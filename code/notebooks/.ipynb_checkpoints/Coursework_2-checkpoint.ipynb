# %% [markdown]
# # Coursework 2
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework2.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    
    return stats, keys

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider
#import os
#os.environ["MLP_DATA_DIR"] = "..\data"

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
#create the test date
test_data = EMNISTDataProvider('test', batch_size=batch_size, rng=rng)
# Out:
# ['inputs', 'targets']
# ['inputs', 'targets']
# ['inputs', 'targets']

# %% [markdown]
# ## PartA 1.   Perform baseline experiments using DNNs trained on EMNIST Balanced.
#
# ### different activation layers such as  SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer....

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


model_SigmoidLayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_ReluLayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_LeakyReluLayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_ELULayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_SELULayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])


# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
#     ReluLayer(),
#     AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
#     ReluLayer(),
#     AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
# ])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('SigmoidLayer\n\n')
[stats_SigmoidLayer, keys_SigmoidLayer] = train_model_and_plot_stats(
    model_SigmoidLayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('ReluLayer\n\n')
[stats_ReluLayer, keys_ReluLayer] = train_model_and_plot_stats(
    model_ReluLayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('LeakyReluLayer\n\n')
[stats_LeakyReluLayer, keys_LeakyReluLayer] = train_model_and_plot_stats(
    model_LeakyReluLayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('ELULayer\n\n')
[stats_ELULayer, keys_ELULayer] = train_model_and_plot_stats(
    model_ELULayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('SELULayer\n\n')
[stats_SELULayer, keys_SELULayer] = train_model_and_plot_stats(
    model_SELULayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_1.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_1.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_1.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different activation layers  in the training dataset')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartA1_activation_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_2.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_2.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_2.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different activation layers  in the valid dataset')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('PartA1_activation_valid_error.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_3.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_3.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_3.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different activation layers  in the training dataset')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartA1_activation_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_4.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_4.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_4.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different activation layers  in the valid dataset')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartA1_activation_valid_acc.pdf') # Save figure to current directory in PDF format

# %% [markdown]
# # PartA 1. Perform baseline experiments using DNNs trained on EMNIST Balanced.
# ## explore the performance of different learning rate on the selected activatoion function Relu. I change the learning rate to 0.01 and 0.001

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

#learning_rate = 0.1
model_ReluLayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

#learning_rate = 0.01
model_ReluLayer_changeLearnRate = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_ReluLayer_changeLearnRate01 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
#     ReluLayer(),
#     AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
#     ReluLayer(),
#     AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
# ])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=0.1)
learning_rule_change = GradientDescentLearningRule(learning_rate=0.01)
learning_rule_change01 = GradientDescentLearningRule(learning_rate=0.001)

#Remember to use notebook=False when you write a script to be run in a terminal
print('ReluLayer learning rate 0.1\n\n')
[stats_ReluLayer, keys_ReluLayer] = train_model_and_plot_stats(
    model_ReluLayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('ReluLayer learning rate 0.01\n\n')
[stats_ReluLayerLearnRate, keys_ReluLayerLearnRate] = train_model_and_plot_stats(
    model_ReluLayer_changeLearnRate, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('ReluLayer learning rate 0.001\n\n')
[stats_ReluLayerLearnRate01, keys_ReluLayerLearnRate01] = train_model_and_plot_stats(
    model_ReluLayer_changeLearnRate01, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
              stats_ReluLayer[1:, keys_ReluLayer[k]], label='Learning_rate:0.1')
    ax_1.plot(np.arange(1, stats_ReluLayerLearnRate.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate[1:, keys_ReluLayer[k]], label='Learning_rate:0.01')
    ax_1.plot(np.arange(1, stats_ReluLayerLearnRate01.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate01[1:, keys_ReluLayer[k]], label='Learning_rate:0.001')

ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different learning rate of ReluLayer on training set')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartA1_ReluLearningRate_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
              stats_ReluLayer[1:, keys_ReluLayer[k]], label='Learning_rate:0.1')
    ax_2.plot(np.arange(1, stats_ReluLayerLearnRate.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate[1:, keys_ReluLayer[k]], label='Learning_rate:0.01')
    ax_2.plot(np.arange(1, stats_ReluLayerLearnRate01.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate01[1:, keys_ReluLayer[k]], label='Learning_rate:0.001')

ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different learning rate of ReluLayer on valid dataset')
fig_2.tight_layout()  # This minimises whitespace around the axes.
fig_2.savefig('PartA1_ReluLearningRate_valid_error.pdf')  # Save figure to current directory in PDF format
#

fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
              stats_ReluLayer[1:, keys_ReluLayer[k]], label='Learning_rate:0.1')
    ax_3.plot(np.arange(1, stats_ReluLayerLearnRate.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate[1:, keys_ReluLayer[k]], label='Learning_rate:0.01')
    ax_3.plot(np.arange(1, stats_ReluLayerLearnRate01.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate01[1:, keys_ReluLayer[k]], label='Learning_rate:0.001')
ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different learning rate of ReluLayer on training dataset')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartA1_ReluLearningRate_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
              stats_ReluLayer[1:, keys_ReluLayer[k]], label='Learning_rate:0.1')
    ax_4.plot(np.arange(1, stats_ReluLayerLearnRate.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate[1:, keys_ReluLayer[k]], label='Learning_rate:0.01')
    ax_4.plot(np.arange(1, stats_ReluLayerLearnRate01.shape[0]) * stats_interval,
              stats_ReluLayerLearnRate01[1:, keys_ReluLayer[k]], label='Learning_rate:0.001')
ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different learning rate of ReluLayer on valid dataset')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartA1_ReluLearningRate_valid_acc.pdf') # Save figure to current directory in PDF format

# %% [markdown]
# # PartA1. Perform baseline experiments using DNNs trained on EMNIST Balanced.
# ## add the dropoutlayer (pro=0.4),activation function is still Relu, and learning rate is 0.1

# %% [markdown]
# ## PartA 3. Perform experiments to compare stochastic gradient descent, RMSProp, and Adam for deep neural network,training on EMNIST Balanced, building on your earlier baseline experiments. In this experiment, I set the learning rate to 0.1.

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule,RMSPropLearningRule,AdamLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])



error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule_Gradient = GradientDescentLearningRule(learning_rate=learning_rate)
learning_rule_RMS = RMSPropLearningRule(learning_rate=learning_rate)
learning_rule_Adam = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('learning_rule_Gradient\n\n')
[stats_Gradient, keys_Gradient] = train_model_and_plot_stats(
    model, error, learning_rule_Gradient, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_RMS\n\n')
[stats_RMS, keys_RMS] = train_model_and_plot_stats(
    model, error, learning_rule_RMS, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_Adam\n\n')
[stats_Adam, keys_Adam] = train_model_and_plot_stats(
    model, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)



 # Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_1.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_1.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different learning rules in the training dataset (learning rate is 0.1) ')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartA3_learning_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_2.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_2.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different learning rules in the training dataset (learning rate is 0.1) ')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('PartA3_learning_valid_error.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_3.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_3.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different learning rules in the training dataset (learning rate is 0.1) ')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartA3_learning_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_4.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_4.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different learning rules in the training dataset (learning rate is 0.1) ')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartA3_learning_valid_acc.pdf') # Save figure to current directory in PDF format
# Out:
# learning_rule_Gradient
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 5.4s to complete
#     error(train)=3.80e+00, acc(train)=1.40e-01, error(valid)=3.80e+00, acc(valid)=1.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 4.2s to complete
#     error(train)=3.18e+00, acc(train)=2.68e-01, error(valid)=3.18e+00, acc(valid)=2.65e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 4.3s to complete
#     error(train)=2.57e+00, acc(train)=3.82e-01, error(valid)=2.57e+00, acc(valid)=3.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 3.9s to complete
#     error(train)=2.24e+00, acc(train)=4.35e-01, error(valid)=2.24e+00, acc(valid)=4.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 4.2s to complete
#     error(train)=2.04e+00, acc(train)=4.98e-01, error(valid)=2.05e+00, acc(valid)=4.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 3.9s to complete
#     error(train)=1.89e+00, acc(train)=5.25e-01, error(valid)=1.90e+00, acc(valid)=5.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 4.8s to complete
#     error(train)=1.80e+00, acc(train)=5.48e-01, error(valid)=1.80e+00, acc(valid)=5.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 4.8s to complete
#     error(train)=1.70e+00, acc(train)=5.62e-01, error(valid)=1.70e+00, acc(valid)=5.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 4.0s to complete
#     error(train)=1.62e+00, acc(train)=5.75e-01, error(valid)=1.63e+00, acc(valid)=5.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 4.6s to complete
#     error(train)=1.57e+00, acc(train)=5.91e-01, error(valid)=1.58e+00, acc(valid)=5.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 4.7s to complete
#     error(train)=1.53e+00, acc(train)=5.98e-01, error(valid)=1.53e+00, acc(valid)=5.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 3.7s to complete
#     error(train)=1.47e+00, acc(train)=6.15e-01, error(valid)=1.48e+00, acc(valid)=6.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 4.9s to complete
#     error(train)=1.43e+00, acc(train)=6.17e-01, error(valid)=1.44e+00, acc(valid)=6.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 4.0s to complete
#     error(train)=1.41e+00, acc(train)=6.28e-01, error(valid)=1.41e+00, acc(valid)=6.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 4.2s to complete
#     error(train)=1.40e+00, acc(train)=6.27e-01, error(valid)=1.40e+00, acc(valid)=6.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 4.5s to complete
#     error(train)=1.36e+00, acc(train)=6.40e-01, error(valid)=1.37e+00, acc(valid)=6.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 3.9s to complete
#     error(train)=1.36e+00, acc(train)=6.43e-01, error(valid)=1.37e+00, acc(valid)=6.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 4.1s to complete
#     error(train)=1.33e+00, acc(train)=6.47e-01, error(valid)=1.34e+00, acc(valid)=6.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 3.7s to complete
#     error(train)=1.31e+00, acc(train)=6.45e-01, error(valid)=1.32e+00, acc(valid)=6.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 3.8s to complete
#     error(train)=1.31e+00, acc(train)=6.50e-01, error(valid)=1.32e+00, acc(valid)=6.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 5.3s to complete
#     error(train)=1.28e+00, acc(train)=6.55e-01, error(valid)=1.29e+00, acc(valid)=6.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 4.8s to complete
#     error(train)=1.28e+00, acc(train)=6.57e-01, error(valid)=1.29e+00, acc(valid)=6.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 4.5s to complete
#     error(train)=1.26e+00, acc(train)=6.59e-01, error(valid)=1.27e+00, acc(valid)=6.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 5.1s to complete
#     error(train)=1.25e+00, acc(train)=6.57e-01, error(valid)=1.25e+00, acc(valid)=6.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 3.9s to complete
#     error(train)=1.25e+00, acc(train)=6.63e-01, error(valid)=1.25e+00, acc(valid)=6.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 4.3s to complete
#     error(train)=1.22e+00, acc(train)=6.68e-01, error(valid)=1.23e+00, acc(valid)=6.65e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 3.9s to complete
#     error(train)=1.21e+00, acc(train)=6.59e-01, error(valid)=1.21e+00, acc(valid)=6.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 4.2s to complete
#     error(train)=1.22e+00, acc(train)=6.67e-01, error(valid)=1.23e+00, acc(valid)=6.64e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 4.3s to complete
#     error(train)=1.19e+00, acc(train)=6.68e-01, error(valid)=1.20e+00, acc(valid)=6.64e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 3.8s to complete
#     error(train)=1.18e+00, acc(train)=6.73e-01, error(valid)=1.19e+00, acc(valid)=6.70e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 3.8s to complete
#     error(train)=1.19e+00, acc(train)=6.71e-01, error(valid)=1.19e+00, acc(valid)=6.68e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 3.8s to complete
#     error(train)=1.19e+00, acc(train)=6.72e-01, error(valid)=1.20e+00, acc(valid)=6.69e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 3.7s to complete
#     error(train)=1.17e+00, acc(train)=6.74e-01, error(valid)=1.18e+00, acc(valid)=6.70e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 3.8s to complete
#     error(train)=1.17e+00, acc(train)=6.75e-01, error(valid)=1.17e+00, acc(valid)=6.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 3.7s to complete
#     error(train)=1.17e+00, acc(train)=6.76e-01, error(valid)=1.18e+00, acc(valid)=6.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 3.9s to complete
#     error(train)=1.15e+00, acc(train)=6.77e-01, error(valid)=1.16e+00, acc(valid)=6.71e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 3.8s to complete
#     error(train)=1.15e+00, acc(train)=6.84e-01, error(valid)=1.16e+00, acc(valid)=6.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 5.3s to complete
#     error(train)=1.16e+00, acc(train)=6.77e-01, error(valid)=1.17e+00, acc(valid)=6.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 4.2s to complete
#     error(train)=1.14e+00, acc(train)=6.77e-01, error(valid)=1.15e+00, acc(valid)=6.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 3.8s to complete
#     error(train)=1.14e+00, acc(train)=6.80e-01, error(valid)=1.15e+00, acc(valid)=6.77e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 4.7s to complete
#     error(train)=1.15e+00, acc(train)=6.76e-01, error(valid)=1.15e+00, acc(valid)=6.72e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 5.1s to complete
#     error(train)=1.13e+00, acc(train)=6.80e-01, error(valid)=1.14e+00, acc(valid)=6.78e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 4.7s to complete
#     error(train)=1.13e+00, acc(train)=6.82e-01, error(valid)=1.14e+00, acc(valid)=6.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 4.6s to complete
#     error(train)=1.12e+00, acc(train)=6.84e-01, error(valid)=1.12e+00, acc(valid)=6.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 4.9s to complete
#     error(train)=1.12e+00, acc(train)=6.84e-01, error(valid)=1.13e+00, acc(valid)=6.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 4.0s to complete
#     error(train)=1.15e+00, acc(train)=6.85e-01, error(valid)=1.15e+00, acc(valid)=6.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 5.0s to complete
#     error(train)=1.12e+00, acc(train)=6.84e-01, error(valid)=1.13e+00, acc(valid)=6.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 4.5s to complete
#     error(train)=1.11e+00, acc(train)=6.85e-01, error(valid)=1.12e+00, acc(valid)=6.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 4.1s to complete
#     error(train)=1.11e+00, acc(train)=6.87e-01, error(valid)=1.12e+00, acc(valid)=6.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 4.6s to complete
#     error(train)=1.11e+00, acc(train)=6.84e-01, error(valid)=1.12e+00, acc(valid)=6.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 3.8s to complete
#     error(train)=1.11e+00, acc(train)=6.88e-01, error(valid)=1.11e+00, acc(valid)=6.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 4.0s to complete
#     error(train)=1.10e+00, acc(train)=6.86e-01, error(valid)=1.10e+00, acc(valid)=6.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 4.1s to complete
#     error(train)=1.10e+00, acc(train)=6.92e-01, error(valid)=1.11e+00, acc(valid)=6.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 3.8s to complete
#     error(train)=1.09e+00, acc(train)=6.93e-01, error(valid)=1.10e+00, acc(valid)=6.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 4.0s to complete
#     error(train)=1.08e+00, acc(train)=6.93e-01, error(valid)=1.09e+00, acc(valid)=6.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 3.7s to complete
#     error(train)=1.09e+00, acc(train)=6.93e-01, error(valid)=1.09e+00, acc(valid)=6.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 3.9s to complete
#     error(train)=1.09e+00, acc(train)=6.85e-01, error(valid)=1.10e+00, acc(valid)=6.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 3.7s to complete
#     error(train)=1.08e+00, acc(train)=6.94e-01, error(valid)=1.09e+00, acc(valid)=6.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 3.7s to complete
#     error(train)=1.07e+00, acc(train)=6.94e-01, error(valid)=1.08e+00, acc(valid)=6.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 4.0s to complete
#     error(train)=1.08e+00, acc(train)=6.97e-01, error(valid)=1.09e+00, acc(valid)=6.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 3.7s to complete
#     error(train)=1.09e+00, acc(train)=6.90e-01, error(valid)=1.10e+00, acc(valid)=6.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 3.9s to complete
#     error(train)=1.08e+00, acc(train)=6.90e-01, error(valid)=1.09e+00, acc(valid)=6.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 4.6s to complete
#     error(train)=1.07e+00, acc(train)=6.96e-01, error(valid)=1.08e+00, acc(valid)=6.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 3.8s to complete
#     error(train)=1.07e+00, acc(train)=6.94e-01, error(valid)=1.08e+00, acc(valid)=6.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 5.0s to complete
#     error(train)=1.07e+00, acc(train)=6.97e-01, error(valid)=1.08e+00, acc(valid)=6.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 4.4s to complete
#     error(train)=1.06e+00, acc(train)=6.91e-01, error(valid)=1.07e+00, acc(valid)=6.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 4.6s to complete
#     error(train)=1.07e+00, acc(train)=6.93e-01, error(valid)=1.08e+00, acc(valid)=6.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 5.0s to complete
#     error(train)=1.07e+00, acc(train)=6.92e-01, error(valid)=1.08e+00, acc(valid)=6.90e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 5.0s to complete
#     error(train)=1.06e+00, acc(train)=6.98e-01, error(valid)=1.07e+00, acc(valid)=6.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 4.2s to complete
#     error(train)=1.06e+00, acc(train)=6.93e-01, error(valid)=1.07e+00, acc(valid)=6.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 5.2s to complete
#     error(train)=1.06e+00, acc(train)=6.95e-01, error(valid)=1.06e+00, acc(valid)=6.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 4.9s to complete
#     error(train)=1.06e+00, acc(train)=6.96e-01, error(valid)=1.07e+00, acc(valid)=6.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 4.2s to complete
#     error(train)=1.06e+00, acc(train)=6.97e-01, error(valid)=1.07e+00, acc(valid)=6.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 4.2s to complete
#     error(train)=1.05e+00, acc(train)=6.99e-01, error(valid)=1.06e+00, acc(valid)=6.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 4.2s to complete
#     error(train)=1.06e+00, acc(train)=7.00e-01, error(valid)=1.07e+00, acc(valid)=6.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 4.5s to complete
#     error(train)=1.06e+00, acc(train)=7.02e-01, error(valid)=1.07e+00, acc(valid)=6.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 4.4s to complete
#     error(train)=1.05e+00, acc(train)=7.01e-01, error(valid)=1.06e+00, acc(valid)=6.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 4.8s to complete
#     error(train)=1.05e+00, acc(train)=6.96e-01, error(valid)=1.06e+00, acc(valid)=6.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 3.8s to complete
#     error(train)=1.05e+00, acc(train)=6.96e-01, error(valid)=1.05e+00, acc(valid)=6.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 4.1s to complete
#     error(train)=1.05e+00, acc(train)=7.00e-01, error(valid)=1.06e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 3.8s to complete
#     error(train)=1.04e+00, acc(train)=7.01e-01, error(valid)=1.05e+00, acc(valid)=6.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 3.9s to complete
#     error(train)=1.04e+00, acc(train)=6.96e-01, error(valid)=1.05e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 3.9s to complete
#     error(train)=1.06e+00, acc(train)=7.00e-01, error(valid)=1.07e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 3.8s to complete
#     error(train)=1.05e+00, acc(train)=6.99e-01, error(valid)=1.06e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 4.1s to complete
#     error(train)=1.05e+00, acc(train)=7.00e-01, error(valid)=1.06e+00, acc(valid)=6.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 3.8s to complete
#     error(train)=1.04e+00, acc(train)=6.97e-01, error(valid)=1.05e+00, acc(valid)=6.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 4.0s to complete
#     error(train)=1.05e+00, acc(train)=7.01e-01, error(valid)=1.06e+00, acc(valid)=6.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 5.6s to complete
#     error(train)=1.03e+00, acc(train)=7.05e-01, error(valid)=1.04e+00, acc(valid)=7.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 4.4s to complete
#     error(train)=1.04e+00, acc(train)=7.03e-01, error(valid)=1.05e+00, acc(valid)=7.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 5.1s to complete
#     error(train)=1.03e+00, acc(train)=7.00e-01, error(valid)=1.04e+00, acc(valid)=6.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 4.8s to complete
#     error(train)=1.04e+00, acc(train)=7.02e-01, error(valid)=1.04e+00, acc(valid)=6.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 3.7s to complete
#     error(train)=1.05e+00, acc(train)=7.02e-01, error(valid)=1.06e+00, acc(valid)=6.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 4.8s to complete
#     error(train)=1.03e+00, acc(train)=7.03e-01, error(valid)=1.03e+00, acc(valid)=7.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 4.4s to complete
#     error(train)=1.03e+00, acc(train)=7.03e-01, error(valid)=1.03e+00, acc(valid)=7.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 4.9s to complete
#     error(train)=1.03e+00, acc(train)=7.10e-01, error(valid)=1.04e+00, acc(valid)=7.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 3.9s to complete
#     error(train)=1.03e+00, acc(train)=7.06e-01, error(valid)=1.04e+00, acc(valid)=7.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 3.9s to complete
#     error(train)=1.02e+00, acc(train)=7.06e-01, error(valid)=1.03e+00, acc(valid)=7.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 4.0s to complete
#     error(train)=1.03e+00, acc(train)=7.05e-01, error(valid)=1.03e+00, acc(valid)=7.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 5.1s to complete
#     error(train)=1.04e+00, acc(train)=7.03e-01, error(valid)=1.05e+00, acc(valid)=7.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 5.0s to complete
#     error(train)=1.03e+00, acc(train)=7.03e-01, error(valid)=1.04e+00, acc(valid)=6.99e-01
# learning_rule_RMS
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 8.2s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 6.7s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.22e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 9.4s to complete
#     error(train)=3.88e+00, acc(train)=2.14e-02, error(valid)=3.88e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.0s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.19e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 5.4s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=1.89e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 5.1s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 6.3s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 8.7s to complete
#     error(train)=3.88e+00, acc(train)=2.13e-02, error(valid)=3.88e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 8.4s to complete
#     error(train)=3.87e+00, acc(train)=2.09e-02, error(valid)=3.87e+00, acc(valid)=2.22e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 8.4s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.03e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 8.5s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.10e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 8.4s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 11.5s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 11.4s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 12.8s to complete
#     error(train)=3.88e+00, acc(train)=2.12e-02, error(valid)=3.88e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 11.8s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 9.8s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 13.2s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 9.2s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 9.6s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.10e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 10.8s to complete
#     error(train)=3.87e+00, acc(train)=2.15e-02, error(valid)=3.87e+00, acc(valid)=2.07e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 9.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 9.2s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.03e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 17.2s to complete
#     error(train)=3.87e+00, acc(train)=2.09e-02, error(valid)=3.87e+00, acc(valid)=2.39e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 12.7s to complete
#     error(train)=3.87e+00, acc(train)=2.09e-02, error(valid)=3.87e+00, acc(valid)=2.22e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 11.7s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.04e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 10.7s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 10.3s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.13e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 13.6s to complete
#     error(train)=3.86e+00, acc(train)=2.09e-02, error(valid)=3.87e+00, acc(valid)=2.23e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 13.0s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 12.5s to complete
#     error(train)=3.86e+00, acc(train)=2.10e-02, error(valid)=3.86e+00, acc(valid)=2.26e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 11.8s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 12.4s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 10.2s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 11.0s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 10.7s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 10.3s to complete
#     error(train)=3.87e+00, acc(train)=2.08e-02, error(valid)=3.86e+00, acc(valid)=2.41e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 10.2s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 10.4s to complete
#     error(train)=3.86e+00, acc(train)=2.09e-02, error(valid)=3.87e+00, acc(valid)=2.39e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 12.8s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=1.89e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 10.6s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.08e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 11.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 11.7s to complete
#     error(train)=3.86e+00, acc(train)=2.15e-02, error(valid)=3.86e+00, acc(valid)=2.04e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 12.0s to complete
#     error(train)=3.87e+00, acc(train)=2.09e-02, error(valid)=3.87e+00, acc(valid)=2.23e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 11.7s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 12.8s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.09e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 11.6s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 11.1s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.88e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 12.3s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 11.8s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 11.8s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.02e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 11.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.28e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 11.7s to complete
#     error(train)=3.86e+00, acc(train)=2.11e-02, error(valid)=3.86e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 11.6s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 11.1s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 11.8s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 11.0s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.14e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 11.8s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.23e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 11.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 11.8s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=2.23e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 11.5s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 11.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 14.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 12.3s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 12.5s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.14e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 12.0s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.86e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 11.5s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 11.5s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 13.1s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 13.2s to complete
#     error(train)=3.87e+00, acc(train)=2.08e-02, error(valid)=3.87e+00, acc(valid)=2.41e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 11.5s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.10e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 12.0s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 11.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.10e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 10.8s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 11.2s to complete
#     error(train)=3.86e+00, acc(train)=2.11e-02, error(valid)=3.86e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 11.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 10.6s to complete
#     error(train)=3.87e+00, acc(train)=2.09e-02, error(valid)=3.86e+00, acc(valid)=2.22e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 10.0s to complete
#     error(train)=3.87e+00, acc(train)=2.08e-02, error(valid)=3.87e+00, acc(valid)=2.41e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 10.0s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=1.89e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 10.1s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.19e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 10.1s to complete
#     error(train)=3.88e+00, acc(train)=2.14e-02, error(valid)=3.88e+00, acc(valid)=1.89e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 10.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 10.7s to complete
#     error(train)=3.88e+00, acc(train)=2.13e-02, error(valid)=3.88e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 11.1s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.96e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 12.5s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 12.9s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 16.1s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.23e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 14.3s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 13.5s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 12.8s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 11.3s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.28e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 12.0s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 12.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.04e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 13.3s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 11.9s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 12.1s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.86e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 12.0s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 10.9s to complete
#     error(train)=3.86e+00, acc(train)=2.09e-02, error(valid)=3.86e+00, acc(valid)=2.39e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 12.1s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.22e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 11.5s to complete
#     error(train)=3.88e+00, acc(train)=2.12e-02, error(valid)=3.88e+00, acc(valid)=2.04e-02
# learning_rule_Adam
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 5.9s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.14e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 5.9s to complete
#     error(train)=3.87e+00, acc(train)=2.09e-02, error(valid)=3.87e+00, acc(valid)=2.22e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 6.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.1s to complete
#     error(train)=3.86e+00, acc(train)=2.11e-02, error(valid)=3.86e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 6.8s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 7.9s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 7.4s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.03e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 8.0s to complete
#     error(train)=3.87e+00, acc(train)=2.08e-02, error(valid)=3.86e+00, acc(valid)=2.41e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 6.5s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=1.88e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 6.0s to complete
#     error(train)=3.86e+00, acc(train)=2.09e-02, error(valid)=3.86e+00, acc(valid)=2.39e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 5.6s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 5.7s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 6.2s to complete
#     error(train)=3.87e+00, acc(train)=2.10e-02, error(valid)=3.87e+00, acc(valid)=2.26e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 5.8s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=1.96e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 7.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.04e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 6.2s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=1.89e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 7.7s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 7.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 7.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 8.2s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 7.7s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 7.8s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 8.1s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 8.2s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 8.5s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.10e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 10.1s to complete
#     error(train)=3.87e+00, acc(train)=2.10e-02, error(valid)=3.87e+00, acc(valid)=2.26e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 9.3s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 12.0s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 9.6s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 8.7s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 8.9s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 9.6s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 8.9s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 9.3s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 10.3s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.02e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 12.0s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 10.0s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.96e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 10.2s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.08e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 12.5s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.86e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 9.2s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.10e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 10.6s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.02e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 10.5s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 11.3s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 9.5s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.23e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 11.8s to complete
#     error(train)=3.87e+00, acc(train)=2.15e-02, error(valid)=3.87e+00, acc(valid)=2.04e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 9.7s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 9.4s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 8.8s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.20e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 10.9s to complete
#     error(train)=3.87e+00, acc(train)=2.10e-02, error(valid)=3.87e+00, acc(valid)=2.26e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 11.6s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.19e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 10.0s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 9.8s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 16.1s to complete
#     error(train)=3.86e+00, acc(train)=2.11e-02, error(valid)=3.86e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 9.9s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 9.0s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=1.89e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 10.0s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 9.4s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 8.9s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.22e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 8.9s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.21e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 9.2s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.28e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 11.1s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 10.8s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 14.6s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 11.3s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 9.2s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 10.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 10.6s to complete
#     error(train)=3.86e+00, acc(train)=2.10e-02, error(valid)=3.86e+00, acc(valid)=2.26e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 11.4s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=2.23e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 10.3s to complete
#     error(train)=3.87e+00, acc(train)=2.15e-02, error(valid)=3.87e+00, acc(valid)=2.04e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 10.4s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.28e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 10.2s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 10.1s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 9.9s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 9.4s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 9.8s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.02e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 10.3s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.08e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 10.1s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 9.6s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 11.2s to complete
#     error(train)=3.86e+00, acc(train)=2.12e-02, error(valid)=3.86e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 9.3s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 9.1s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.15e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 10.3s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 10.6s to complete
#     error(train)=3.86e+00, acc(train)=2.13e-02, error(valid)=3.86e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 10.2s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 9.5s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 12.0s to complete
#     error(train)=3.87e+00, acc(train)=2.15e-02, error(valid)=3.87e+00, acc(valid)=2.07e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 9.3s to complete
#     error(train)=3.86e+00, acc(train)=2.17e-02, error(valid)=3.86e+00, acc(valid)=1.98e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 9.3s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 9.1s to complete
#     error(train)=3.87e+00, acc(train)=2.17e-02, error(valid)=3.87e+00, acc(valid)=1.96e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 9.2s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=2.19e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 16.5s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.10e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 12.1s to complete
#     error(train)=3.87e+00, acc(train)=2.13e-02, error(valid)=3.87e+00, acc(valid)=2.08e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 11.4s to complete
#     error(train)=3.86e+00, acc(train)=2.15e-02, error(valid)=3.86e+00, acc(valid)=1.99e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 12.5s to complete
#     error(train)=3.87e+00, acc(train)=2.11e-02, error(valid)=3.87e+00, acc(valid)=2.14e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 12.0s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.11e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 9.2s to complete
#     error(train)=3.86e+00, acc(train)=2.15e-02, error(valid)=3.86e+00, acc(valid)=1.99e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 10.2s to complete
#     error(train)=3.87e+00, acc(train)=2.14e-02, error(valid)=3.87e+00, acc(valid)=2.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 9.9s to complete
#     error(train)=3.86e+00, acc(train)=2.14e-02, error(valid)=3.86e+00, acc(valid)=2.03e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 9.3s to complete
#     error(train)=3.87e+00, acc(train)=2.12e-02, error(valid)=3.87e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 9.8s to complete
#     error(train)=3.87e+00, acc(train)=2.15e-02, error(valid)=3.87e+00, acc(valid)=1.99e-02

# %% [markdown]
# ## PartA 3.  In this experiment, I set the learning rate to 0.01.

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule,RMSPropLearningRule,AdamLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.01
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])



error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule_Gradient = GradientDescentLearningRule(learning_rate=learning_rate)
learning_rule_RMS = RMSPropLearningRule(learning_rate=learning_rate)
learning_rule_Adam = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('learning_rule_Gradient\n\n')
[stats_Gradient, keys_Gradient] = train_model_and_plot_stats(
    model, error, learning_rule_Gradient, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_RMS\n\n')
[stats_RMS, keys_RMS] = train_model_and_plot_stats(
    model, error, learning_rule_RMS, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_Adam\n\n')
[stats_Adam, keys_Adam] = train_model_and_plot_stats(
    model, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)



 # Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_1.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_1.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different learning rules in the training dataset (learning rate is 0.01) ')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartA3_learning_train_error_001.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_2.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_2.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different learning rules in the training dataset (learning rate is 0.01) ')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('PartA3_learning_valid_error_001.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_3.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_3.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different learning rules in the training dataset (learning rate is 0.01) ')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartA3_learning_train_acc_001.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_4.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_4.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different learning rules in the training dataset (learning rate is 0.01) ')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartA3_learning_valid_acc_001.pdf') # Save figure to current directory in PDF format
#

# %% [markdown]
# # PartA 3.  In this experiment, I set the learning rate to 0.001.

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule,RMSPropLearningRule,AdamLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])



error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule_Gradient = GradientDescentLearningRule(learning_rate=learning_rate)
learning_rule_RMS = RMSPropLearningRule(learning_rate=learning_rate)
learning_rule_Adam = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('learning_rule_Gradient\n\n')
[stats_Gradient, keys_Gradient] = train_model_and_plot_stats(
    model, error, learning_rule_Gradient, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_RMS\n\n')
[stats_RMS, keys_RMS] = train_model_and_plot_stats(
    model, error, learning_rule_RMS, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_Adam\n\n')
[stats_Adam, keys_Adam] = train_model_and_plot_stats(
    model, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)



 # Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_1.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_1.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different learning rules in training dataset (learning rate is 0.001) ')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartA3_learning_train_error_0001.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_2.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_2.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different learning rules in valid dataset (learning rate is 0.001) ')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('PartA3_learning_valid_error_0001.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_3.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_3.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different learning rules in training dataset (learning rate is 0.001) ')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartA3_learning_train_acc_0001.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_4.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_4.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different learning rules in valid dataset (learning rate is 0.001) ')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartA3_learning_valid_acc_0001.pdf') # Save figure to current directory in PDF format
# Out:
# learning_rule_Gradient
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 6.2s to complete
#     error(train)=3.80e+00, acc(train)=5.68e-02, error(valid)=3.80e+00, acc(valid)=5.63e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 3.9s to complete
#     error(train)=3.71e+00, acc(train)=9.31e-02, error(valid)=3.71e+00, acc(valid)=9.14e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 3.9s to complete
#     error(train)=3.61e+00, acc(train)=1.30e-01, error(valid)=3.61e+00, acc(valid)=1.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 3.7s to complete
#     error(train)=3.48e+00, acc(train)=1.71e-01, error(valid)=3.48e+00, acc(valid)=1.74e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 4.2s to complete
#     error(train)=3.32e+00, acc(train)=2.22e-01, error(valid)=3.32e+00, acc(valid)=2.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 7.7s to complete
#     error(train)=3.11e+00, acc(train)=2.75e-01, error(valid)=3.11e+00, acc(valid)=2.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 6.5s to complete
#     error(train)=2.88e+00, acc(train)=3.30e-01, error(valid)=2.88e+00, acc(valid)=3.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 5.5s to complete
#     error(train)=2.64e+00, acc(train)=3.80e-01, error(valid)=2.64e+00, acc(valid)=3.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 4.9s to complete
#     error(train)=2.43e+00, acc(train)=4.20e-01, error(valid)=2.43e+00, acc(valid)=4.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.2s to complete
#     error(train)=2.25e+00, acc(train)=4.54e-01, error(valid)=2.25e+00, acc(valid)=4.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 4.3s to complete
#     error(train)=2.10e+00, acc(train)=4.83e-01, error(valid)=2.09e+00, acc(valid)=4.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 4.4s to complete
#     error(train)=1.97e+00, acc(train)=5.03e-01, error(valid)=1.97e+00, acc(valid)=5.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 4.4s to complete
#     error(train)=1.87e+00, acc(train)=5.21e-01, error(valid)=1.87e+00, acc(valid)=5.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 4.3s to complete
#     error(train)=1.79e+00, acc(train)=5.37e-01, error(valid)=1.78e+00, acc(valid)=5.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 4.2s to complete
#     error(train)=1.72e+00, acc(train)=5.50e-01, error(valid)=1.71e+00, acc(valid)=5.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 4.1s to complete
#     error(train)=1.66e+00, acc(train)=5.61e-01, error(valid)=1.66e+00, acc(valid)=5.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 3.5s to complete
#     error(train)=1.61e+00, acc(train)=5.71e-01, error(valid)=1.61e+00, acc(valid)=5.68e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 4.5s to complete
#     error(train)=1.57e+00, acc(train)=5.79e-01, error(valid)=1.57e+00, acc(valid)=5.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 4.1s to complete
#     error(train)=1.54e+00, acc(train)=5.86e-01, error(valid)=1.53e+00, acc(valid)=5.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 4.2s to complete
#     error(train)=1.50e+00, acc(train)=5.93e-01, error(valid)=1.50e+00, acc(valid)=5.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 3.7s to complete
#     error(train)=1.48e+00, acc(train)=5.98e-01, error(valid)=1.48e+00, acc(valid)=5.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 4.4s to complete
#     error(train)=1.45e+00, acc(train)=6.04e-01, error(valid)=1.45e+00, acc(valid)=6.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 4.9s to complete
#     error(train)=1.43e+00, acc(train)=6.08e-01, error(valid)=1.43e+00, acc(valid)=6.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 3.7s to complete
#     error(train)=1.41e+00, acc(train)=6.12e-01, error(valid)=1.41e+00, acc(valid)=6.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 4.0s to complete
#     error(train)=1.40e+00, acc(train)=6.16e-01, error(valid)=1.39e+00, acc(valid)=6.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 4.0s to complete
#     error(train)=1.38e+00, acc(train)=6.20e-01, error(valid)=1.38e+00, acc(valid)=6.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 4.4s to complete
#     error(train)=1.37e+00, acc(train)=6.23e-01, error(valid)=1.36e+00, acc(valid)=6.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 3.9s to complete
#     error(train)=1.35e+00, acc(train)=6.26e-01, error(valid)=1.35e+00, acc(valid)=6.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 4.1s to complete
#     error(train)=1.34e+00, acc(train)=6.29e-01, error(valid)=1.34e+00, acc(valid)=6.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 4.6s to complete
#     error(train)=1.33e+00, acc(train)=6.33e-01, error(valid)=1.33e+00, acc(valid)=6.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 4.3s to complete
#     error(train)=1.31e+00, acc(train)=6.36e-01, error(valid)=1.32e+00, acc(valid)=6.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 4.2s to complete
#     error(train)=1.30e+00, acc(train)=6.38e-01, error(valid)=1.30e+00, acc(valid)=6.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 3.4s to complete
#     error(train)=1.29e+00, acc(train)=6.40e-01, error(valid)=1.29e+00, acc(valid)=6.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 3.5s to complete
#     error(train)=1.28e+00, acc(train)=6.43e-01, error(valid)=1.28e+00, acc(valid)=6.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 3.4s to complete
#     error(train)=1.27e+00, acc(train)=6.45e-01, error(valid)=1.28e+00, acc(valid)=6.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 3.4s to complete
#     error(train)=1.27e+00, acc(train)=6.47e-01, error(valid)=1.27e+00, acc(valid)=6.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 3.5s to complete
#     error(train)=1.26e+00, acc(train)=6.50e-01, error(valid)=1.26e+00, acc(valid)=6.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 3.6s to complete
#     error(train)=1.25e+00, acc(train)=6.52e-01, error(valid)=1.25e+00, acc(valid)=6.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 3.9s to complete
#     error(train)=1.24e+00, acc(train)=6.53e-01, error(valid)=1.24e+00, acc(valid)=6.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 3.7s to complete
#     error(train)=1.23e+00, acc(train)=6.56e-01, error(valid)=1.24e+00, acc(valid)=6.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 6.1s to complete
#     error(train)=1.23e+00, acc(train)=6.58e-01, error(valid)=1.23e+00, acc(valid)=6.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 4.6s to complete
#     error(train)=1.22e+00, acc(train)=6.60e-01, error(valid)=1.22e+00, acc(valid)=6.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 4.0s to complete
#     error(train)=1.21e+00, acc(train)=6.63e-01, error(valid)=1.21e+00, acc(valid)=6.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 4.3s to complete
#     error(train)=1.20e+00, acc(train)=6.65e-01, error(valid)=1.21e+00, acc(valid)=6.64e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 3.6s to complete
#     error(train)=1.20e+00, acc(train)=6.66e-01, error(valid)=1.20e+00, acc(valid)=6.66e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 4.1s to complete
#     error(train)=1.19e+00, acc(train)=6.68e-01, error(valid)=1.19e+00, acc(valid)=6.68e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 3.8s to complete
#     error(train)=1.18e+00, acc(train)=6.70e-01, error(valid)=1.19e+00, acc(valid)=6.68e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 4.3s to complete
#     error(train)=1.18e+00, acc(train)=6.71e-01, error(valid)=1.18e+00, acc(valid)=6.70e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 4.0s to complete
#     error(train)=1.17e+00, acc(train)=6.73e-01, error(valid)=1.18e+00, acc(valid)=6.72e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 3.3s to complete
#     error(train)=1.16e+00, acc(train)=6.74e-01, error(valid)=1.17e+00, acc(valid)=6.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 3.5s to complete
#     error(train)=1.16e+00, acc(train)=6.76e-01, error(valid)=1.16e+00, acc(valid)=6.77e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 3.6s to complete
#     error(train)=1.15e+00, acc(train)=6.77e-01, error(valid)=1.16e+00, acc(valid)=6.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 3.7s to complete
#     error(train)=1.15e+00, acc(train)=6.79e-01, error(valid)=1.15e+00, acc(valid)=6.78e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 3.3s to complete
#     error(train)=1.14e+00, acc(train)=6.81e-01, error(valid)=1.15e+00, acc(valid)=6.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 4.5s to complete
#     error(train)=1.13e+00, acc(train)=6.82e-01, error(valid)=1.14e+00, acc(valid)=6.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 3.5s to complete
#     error(train)=1.13e+00, acc(train)=6.84e-01, error(valid)=1.14e+00, acc(valid)=6.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 3.6s to complete
#     error(train)=1.12e+00, acc(train)=6.85e-01, error(valid)=1.13e+00, acc(valid)=6.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 3.3s to complete
#     error(train)=1.12e+00, acc(train)=6.86e-01, error(valid)=1.13e+00, acc(valid)=6.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 3.4s to complete
#     error(train)=1.11e+00, acc(train)=6.88e-01, error(valid)=1.12e+00, acc(valid)=6.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 3.4s to complete
#     error(train)=1.11e+00, acc(train)=6.88e-01, error(valid)=1.12e+00, acc(valid)=6.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 3.3s to complete
#     error(train)=1.10e+00, acc(train)=6.91e-01, error(valid)=1.11e+00, acc(valid)=6.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 3.8s to complete
#     error(train)=1.10e+00, acc(train)=6.92e-01, error(valid)=1.11e+00, acc(valid)=6.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 3.9s to complete
#     error(train)=1.09e+00, acc(train)=6.94e-01, error(valid)=1.10e+00, acc(valid)=6.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 3.8s to complete
#     error(train)=1.09e+00, acc(train)=6.95e-01, error(valid)=1.10e+00, acc(valid)=6.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 3.7s to complete
#     error(train)=1.08e+00, acc(train)=6.96e-01, error(valid)=1.09e+00, acc(valid)=6.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 3.7s to complete
#     error(train)=1.08e+00, acc(train)=6.97e-01, error(valid)=1.09e+00, acc(valid)=6.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 4.6s to complete
#     error(train)=1.07e+00, acc(train)=6.98e-01, error(valid)=1.08e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 3.7s to complete
#     error(train)=1.07e+00, acc(train)=7.00e-01, error(valid)=1.08e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 4.0s to complete
#     error(train)=1.06e+00, acc(train)=7.01e-01, error(valid)=1.07e+00, acc(valid)=6.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 3.8s to complete
#     error(train)=1.06e+00, acc(train)=7.01e-01, error(valid)=1.07e+00, acc(valid)=6.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 4.0s to complete
#     error(train)=1.05e+00, acc(train)=7.03e-01, error(valid)=1.06e+00, acc(valid)=7.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 3.6s to complete
#     error(train)=1.05e+00, acc(train)=7.05e-01, error(valid)=1.06e+00, acc(valid)=7.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 4.6s to complete
#     error(train)=1.04e+00, acc(train)=7.05e-01, error(valid)=1.06e+00, acc(valid)=7.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 4.4s to complete
#     error(train)=1.04e+00, acc(train)=7.07e-01, error(valid)=1.05e+00, acc(valid)=7.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 4.2s to complete
#     error(train)=1.03e+00, acc(train)=7.07e-01, error(valid)=1.05e+00, acc(valid)=7.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 5.0s to complete
#     error(train)=1.03e+00, acc(train)=7.09e-01, error(valid)=1.04e+00, acc(valid)=7.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 3.7s to complete
#     error(train)=1.02e+00, acc(train)=7.10e-01, error(valid)=1.04e+00, acc(valid)=7.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 4.4s to complete
#     error(train)=1.02e+00, acc(train)=7.11e-01, error(valid)=1.04e+00, acc(valid)=7.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 6.4s to complete
#     error(train)=1.02e+00, acc(train)=7.12e-01, error(valid)=1.03e+00, acc(valid)=7.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 5.1s to complete
#     error(train)=1.01e+00, acc(train)=7.13e-01, error(valid)=1.03e+00, acc(valid)=7.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 4.6s to complete
#     error(train)=1.01e+00, acc(train)=7.14e-01, error(valid)=1.02e+00, acc(valid)=7.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 3.8s to complete
#     error(train)=1.00e+00, acc(train)=7.15e-01, error(valid)=1.02e+00, acc(valid)=7.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 4.3s to complete
#     error(train)=1.00e+00, acc(train)=7.16e-01, error(valid)=1.02e+00, acc(valid)=7.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 4.2s to complete
#     error(train)=9.96e-01, acc(train)=7.18e-01, error(valid)=1.01e+00, acc(valid)=7.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 4.1s to complete
#     error(train)=9.93e-01, acc(train)=7.19e-01, error(valid)=1.01e+00, acc(valid)=7.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 4.4s to complete
#     error(train)=9.88e-01, acc(train)=7.20e-01, error(valid)=1.00e+00, acc(valid)=7.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 3.9s to complete
#     error(train)=9.84e-01, acc(train)=7.21e-01, error(valid)=1.00e+00, acc(valid)=7.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 3.8s to complete
#     error(train)=9.81e-01, acc(train)=7.21e-01, error(valid)=9.97e-01, acc(valid)=7.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 4.6s to complete
#     error(train)=9.77e-01, acc(train)=7.22e-01, error(valid)=9.93e-01, acc(valid)=7.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 3.8s to complete
#     error(train)=9.73e-01, acc(train)=7.23e-01, error(valid)=9.89e-01, acc(valid)=7.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 4.1s to complete
#     error(train)=9.69e-01, acc(train)=7.25e-01, error(valid)=9.85e-01, acc(valid)=7.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 3.7s to complete
#     error(train)=9.66e-01, acc(train)=7.25e-01, error(valid)=9.82e-01, acc(valid)=7.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 4.1s to complete
#     error(train)=9.62e-01, acc(train)=7.26e-01, error(valid)=9.78e-01, acc(valid)=7.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 3.6s to complete
#     error(train)=9.58e-01, acc(train)=7.27e-01, error(valid)=9.75e-01, acc(valid)=7.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 3.7s to complete
#     error(train)=9.55e-01, acc(train)=7.27e-01, error(valid)=9.71e-01, acc(valid)=7.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 3.9s to complete
#     error(train)=9.51e-01, acc(train)=7.29e-01, error(valid)=9.69e-01, acc(valid)=7.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 4.4s to complete
#     error(train)=9.48e-01, acc(train)=7.29e-01, error(valid)=9.65e-01, acc(valid)=7.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 5.0s to complete
#     error(train)=9.44e-01, acc(train)=7.30e-01, error(valid)=9.62e-01, acc(valid)=7.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 3.8s to complete
#     error(train)=9.41e-01, acc(train)=7.31e-01, error(valid)=9.58e-01, acc(valid)=7.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 5.0s to complete
#     error(train)=9.37e-01, acc(train)=7.32e-01, error(valid)=9.55e-01, acc(valid)=7.29e-01
# learning_rule_RMS
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 5.3s to complete
#     error(train)=7.05e-01, acc(train)=7.85e-01, error(valid)=7.42e-01, acc(valid)=7.72e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 6.2s to complete
#     error(train)=6.13e-01, acc(train)=8.10e-01, error(valid)=6.61e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 5.2s to complete
#     error(train)=5.44e-01, acc(train)=8.24e-01, error(valid)=6.06e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.2s to complete
#     error(train)=5.06e-01, acc(train)=8.33e-01, error(valid)=5.81e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 6.5s to complete
#     error(train)=4.73e-01, acc(train)=8.42e-01, error(valid)=5.61e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 6.4s to complete
#     error(train)=4.41e-01, acc(train)=8.53e-01, error(valid)=5.36e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 5.6s to complete
#     error(train)=4.15e-01, acc(train)=8.60e-01, error(valid)=5.26e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 7.2s to complete
#     error(train)=4.04e-01, acc(train)=8.64e-01, error(valid)=5.33e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 5.4s to complete
#     error(train)=3.91e-01, acc(train)=8.67e-01, error(valid)=5.31e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.8s to complete
#     error(train)=3.97e-01, acc(train)=8.64e-01, error(valid)=5.52e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 5.9s to complete
#     error(train)=3.83e-01, acc(train)=8.65e-01, error(valid)=5.44e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 5.5s to complete
#     error(train)=3.51e-01, acc(train)=8.79e-01, error(valid)=5.26e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 4.6s to complete
#     error(train)=3.67e-01, acc(train)=8.73e-01, error(valid)=5.60e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 5.2s to complete
#     error(train)=3.66e-01, acc(train)=8.72e-01, error(valid)=5.59e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 4.5s to complete
#     error(train)=3.62e-01, acc(train)=8.72e-01, error(valid)=5.82e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 5.4s to complete
#     error(train)=3.37e-01, acc(train)=8.80e-01, error(valid)=5.72e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 5.7s to complete
#     error(train)=3.27e-01, acc(train)=8.85e-01, error(valid)=5.81e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 4.8s to complete
#     error(train)=3.22e-01, acc(train)=8.86e-01, error(valid)=5.89e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 5.5s to complete
#     error(train)=3.16e-01, acc(train)=8.88e-01, error(valid)=5.82e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 6.6s to complete
#     error(train)=3.26e-01, acc(train)=8.84e-01, error(valid)=6.02e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 5.9s to complete
#     error(train)=3.29e-01, acc(train)=8.82e-01, error(valid)=6.37e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 5.3s to complete
#     error(train)=3.13e-01, acc(train)=8.86e-01, error(valid)=6.10e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 5.1s to complete
#     error(train)=3.02e-01, acc(train)=8.91e-01, error(valid)=6.19e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 5.4s to complete
#     error(train)=3.02e-01, acc(train)=8.91e-01, error(valid)=6.31e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 4.9s to complete
#     error(train)=2.98e-01, acc(train)=8.92e-01, error(valid)=6.48e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 4.8s to complete
#     error(train)=2.87e-01, acc(train)=8.96e-01, error(valid)=6.62e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 5.5s to complete
#     error(train)=2.89e-01, acc(train)=8.95e-01, error(valid)=6.56e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 5.1s to complete
#     error(train)=2.88e-01, acc(train)=8.95e-01, error(valid)=6.79e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 5.4s to complete
#     error(train)=2.93e-01, acc(train)=8.93e-01, error(valid)=6.93e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 5.2s to complete
#     error(train)=3.01e-01, acc(train)=8.91e-01, error(valid)=7.23e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 5.0s to complete
#     error(train)=2.86e-01, acc(train)=8.95e-01, error(valid)=6.92e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 5.4s to complete
#     error(train)=2.80e-01, acc(train)=8.97e-01, error(valid)=7.11e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 5.1s to complete
#     error(train)=3.01e-01, acc(train)=8.90e-01, error(valid)=7.43e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 5.1s to complete
#     error(train)=2.85e-01, acc(train)=8.94e-01, error(valid)=7.40e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 5.2s to complete
#     error(train)=2.85e-01, acc(train)=8.97e-01, error(valid)=7.69e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 7.4s to complete
#     error(train)=2.71e-01, acc(train)=8.99e-01, error(valid)=7.27e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 6.6s to complete
#     error(train)=3.08e-01, acc(train)=8.89e-01, error(valid)=7.92e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 5.9s to complete
#     error(train)=2.75e-01, acc(train)=8.99e-01, error(valid)=7.85e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 5.7s to complete
#     error(train)=2.85e-01, acc(train)=8.95e-01, error(valid)=7.94e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 6.4s to complete
#     error(train)=2.74e-01, acc(train)=8.99e-01, error(valid)=8.37e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 6.6s to complete
#     error(train)=2.64e-01, acc(train)=9.04e-01, error(valid)=8.12e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 6.4s to complete
#     error(train)=2.84e-01, acc(train)=8.93e-01, error(valid)=8.25e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 7.1s to complete
#     error(train)=2.65e-01, acc(train)=9.02e-01, error(valid)=8.53e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 5.5s to complete
#     error(train)=2.60e-01, acc(train)=9.04e-01, error(valid)=8.25e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 5.7s to complete
#     error(train)=2.78e-01, acc(train)=8.98e-01, error(valid)=8.84e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 5.9s to complete
#     error(train)=2.65e-01, acc(train)=9.03e-01, error(valid)=8.74e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 6.1s to complete
#     error(train)=2.72e-01, acc(train)=9.00e-01, error(valid)=9.25e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 6.2s to complete
#     error(train)=2.53e-01, acc(train)=9.05e-01, error(valid)=8.77e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 5.3s to complete
#     error(train)=2.62e-01, acc(train)=9.02e-01, error(valid)=8.86e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 5.6s to complete
#     error(train)=2.52e-01, acc(train)=9.07e-01, error(valid)=9.36e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 6.3s to complete
#     error(train)=2.46e-01, acc(train)=9.11e-01, error(valid)=9.33e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 6.3s to complete
#     error(train)=2.60e-01, acc(train)=9.04e-01, error(valid)=9.43e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 6.1s to complete
#     error(train)=2.73e-01, acc(train)=9.01e-01, error(valid)=9.74e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 5.9s to complete
#     error(train)=2.57e-01, acc(train)=9.08e-01, error(valid)=9.98e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 7.2s to complete
#     error(train)=2.91e-01, acc(train)=9.01e-01, error(valid)=1.12e+00, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 5.4s to complete
#     error(train)=2.49e-01, acc(train)=9.10e-01, error(valid)=1.02e+00, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 5.8s to complete
#     error(train)=2.55e-01, acc(train)=9.05e-01, error(valid)=1.00e+00, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 5.5s to complete
#     error(train)=2.65e-01, acc(train)=9.02e-01, error(valid)=1.01e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 5.2s to complete
#     error(train)=2.54e-01, acc(train)=9.07e-01, error(valid)=1.04e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 5.5s to complete
#     error(train)=2.39e-01, acc(train)=9.11e-01, error(valid)=1.03e+00, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 5.0s to complete
#     error(train)=2.49e-01, acc(train)=9.08e-01, error(valid)=1.06e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 5.1s to complete
#     error(train)=2.60e-01, acc(train)=9.07e-01, error(valid)=1.11e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 5.0s to complete
#     error(train)=2.43e-01, acc(train)=9.12e-01, error(valid)=1.10e+00, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 5.1s to complete
#     error(train)=2.53e-01, acc(train)=9.08e-01, error(valid)=1.14e+00, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 4.9s to complete
#     error(train)=2.57e-01, acc(train)=9.05e-01, error(valid)=1.11e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 5.0s to complete
#     error(train)=2.50e-01, acc(train)=9.08e-01, error(valid)=1.12e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 5.1s to complete
#     error(train)=2.50e-01, acc(train)=9.10e-01, error(valid)=1.19e+00, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 5.4s to complete
#     error(train)=2.40e-01, acc(train)=9.11e-01, error(valid)=1.15e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 4.9s to complete
#     error(train)=2.69e-01, acc(train)=9.02e-01, error(valid)=1.14e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 5.5s to complete
#     error(train)=2.43e-01, acc(train)=9.11e-01, error(valid)=1.19e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 5.5s to complete
#     error(train)=2.70e-01, acc(train)=9.03e-01, error(valid)=1.21e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 5.2s to complete
#     error(train)=2.65e-01, acc(train)=9.02e-01, error(valid)=1.17e+00, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 5.0s to complete
#     error(train)=2.39e-01, acc(train)=9.13e-01, error(valid)=1.24e+00, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 5.2s to complete
#     error(train)=2.46e-01, acc(train)=9.07e-01, error(valid)=1.16e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 7.0s to complete
#     error(train)=2.47e-01, acc(train)=9.09e-01, error(valid)=1.20e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 5.8s to complete
#     error(train)=2.33e-01, acc(train)=9.16e-01, error(valid)=1.27e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 5.7s to complete
#     error(train)=2.47e-01, acc(train)=9.13e-01, error(valid)=1.36e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 5.0s to complete
#     error(train)=2.56e-01, acc(train)=9.05e-01, error(valid)=1.25e+00, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 5.3s to complete
#     error(train)=2.59e-01, acc(train)=9.10e-01, error(valid)=1.32e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 5.6s to complete
#     error(train)=2.69e-01, acc(train)=9.02e-01, error(valid)=1.30e+00, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 4.7s to complete
#     error(train)=2.57e-01, acc(train)=9.08e-01, error(valid)=1.36e+00, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 4.7s to complete
#     error(train)=2.63e-01, acc(train)=9.03e-01, error(valid)=1.31e+00, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 5.1s to complete
#     error(train)=2.69e-01, acc(train)=9.09e-01, error(valid)=1.42e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 4.8s to complete
#     error(train)=2.57e-01, acc(train)=9.08e-01, error(valid)=1.38e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 5.7s to complete
#     error(train)=2.38e-01, acc(train)=9.12e-01, error(valid)=1.32e+00, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 5.4s to complete
#     error(train)=2.45e-01, acc(train)=9.12e-01, error(valid)=1.44e+00, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 5.2s to complete
#     error(train)=2.37e-01, acc(train)=9.15e-01, error(valid)=1.39e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 5.1s to complete
#     error(train)=2.35e-01, acc(train)=9.15e-01, error(valid)=1.40e+00, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 6.4s to complete
#     error(train)=2.22e-01, acc(train)=9.20e-01, error(valid)=1.41e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 7.0s to complete
#     error(train)=2.43e-01, acc(train)=9.11e-01, error(valid)=1.44e+00, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 6.5s to complete
#     error(train)=2.51e-01, acc(train)=9.15e-01, error(valid)=1.55e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 6.4s to complete
#     error(train)=2.46e-01, acc(train)=9.16e-01, error(valid)=1.55e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 6.0s to complete
#     error(train)=2.46e-01, acc(train)=9.13e-01, error(valid)=1.50e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 5.5s to complete
#     error(train)=2.47e-01, acc(train)=9.11e-01, error(valid)=1.47e+00, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 5.8s to complete
#     error(train)=2.84e-01, acc(train)=9.01e-01, error(valid)=1.44e+00, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 8.0s to complete
#     error(train)=2.40e-01, acc(train)=9.13e-01, error(valid)=1.48e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 5.3s to complete
#     error(train)=2.40e-01, acc(train)=9.15e-01, error(valid)=1.53e+00, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 5.2s to complete
#     error(train)=2.82e-01, acc(train)=9.06e-01, error(valid)=1.57e+00, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 6.7s to complete
#     error(train)=2.58e-01, acc(train)=9.12e-01, error(valid)=1.64e+00, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 6.4s to complete
#     error(train)=2.44e-01, acc(train)=9.16e-01, error(valid)=1.58e+00, acc(valid)=8.01e-01
# learning_rule_Adam
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 7.0s to complete
#     error(train)=3.79e-01, acc(train)=8.79e-01, error(valid)=1.33e+00, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 7.3s to complete
#     error(train)=3.00e-01, acc(train)=8.99e-01, error(valid)=1.42e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 5.6s to complete
#     error(train)=2.88e-01, acc(train)=9.05e-01, error(valid)=1.50e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.2s to complete
#     error(train)=2.80e-01, acc(train)=9.04e-01, error(valid)=1.46e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 5.7s to complete
#     error(train)=2.44e-01, acc(train)=9.11e-01, error(valid)=1.38e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 5.7s to complete
#     error(train)=2.39e-01, acc(train)=9.13e-01, error(valid)=1.42e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 5.9s to complete
#     error(train)=2.24e-01, acc(train)=9.18e-01, error(valid)=1.44e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 5.5s to complete
#     error(train)=2.58e-01, acc(train)=9.07e-01, error(valid)=1.41e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 5.9s to complete
#     error(train)=2.34e-01, acc(train)=9.14e-01, error(valid)=1.38e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.4s to complete
#     error(train)=2.43e-01, acc(train)=9.09e-01, error(valid)=1.34e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 5.5s to complete
#     error(train)=2.51e-01, acc(train)=9.08e-01, error(valid)=1.42e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 5.1s to complete
#     error(train)=2.45e-01, acc(train)=9.11e-01, error(valid)=1.43e+00, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 5.3s to complete
#     error(train)=2.23e-01, acc(train)=9.16e-01, error(valid)=1.46e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 5.6s to complete
#     error(train)=2.38e-01, acc(train)=9.13e-01, error(valid)=1.49e+00, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 5.5s to complete
#     error(train)=2.15e-01, acc(train)=9.18e-01, error(valid)=1.48e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 5.6s to complete
#     error(train)=2.04e-01, acc(train)=9.23e-01, error(valid)=1.51e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 6.1s to complete
#     error(train)=2.24e-01, acc(train)=9.14e-01, error(valid)=1.42e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 6.0s to complete
#     error(train)=2.29e-01, acc(train)=9.15e-01, error(valid)=1.46e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 5.4s to complete
#     error(train)=2.11e-01, acc(train)=9.20e-01, error(valid)=1.42e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 5.2s to complete
#     error(train)=2.50e-01, acc(train)=9.09e-01, error(valid)=1.45e+00, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 5.5s to complete
#     error(train)=1.90e-01, acc(train)=9.25e-01, error(valid)=1.51e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 5.4s to complete
#     error(train)=1.96e-01, acc(train)=9.23e-01, error(valid)=1.45e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 7.1s to complete
#     error(train)=1.98e-01, acc(train)=9.24e-01, error(valid)=1.49e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 6.5s to complete
#     error(train)=1.93e-01, acc(train)=9.27e-01, error(valid)=1.51e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 5.8s to complete
#     error(train)=1.90e-01, acc(train)=9.26e-01, error(valid)=1.41e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 5.8s to complete
#     error(train)=2.09e-01, acc(train)=9.23e-01, error(valid)=1.57e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 5.7s to complete
#     error(train)=2.09e-01, acc(train)=9.22e-01, error(valid)=1.55e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 6.0s to complete
#     error(train)=1.90e-01, acc(train)=9.25e-01, error(valid)=1.51e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 6.5s to complete
#     error(train)=1.89e-01, acc(train)=9.25e-01, error(valid)=1.53e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 5.5s to complete
#     error(train)=2.09e-01, acc(train)=9.21e-01, error(valid)=1.54e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 5.6s to complete
#     error(train)=2.09e-01, acc(train)=9.21e-01, error(valid)=1.57e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 5.5s to complete
#     error(train)=1.92e-01, acc(train)=9.26e-01, error(valid)=1.49e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 5.8s to complete
#     error(train)=1.94e-01, acc(train)=9.25e-01, error(valid)=1.59e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 6.2s to complete
#     error(train)=1.73e-01, acc(train)=9.31e-01, error(valid)=1.50e+00, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 6.7s to complete
#     error(train)=1.85e-01, acc(train)=9.29e-01, error(valid)=1.52e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 5.6s to complete
#     error(train)=2.01e-01, acc(train)=9.23e-01, error(valid)=1.62e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 7.0s to complete
#     error(train)=1.80e-01, acc(train)=9.28e-01, error(valid)=1.63e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 8.5s to complete
#     error(train)=1.88e-01, acc(train)=9.28e-01, error(valid)=1.59e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 7.2s to complete
#     error(train)=1.69e-01, acc(train)=9.31e-01, error(valid)=1.56e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 6.1s to complete
#     error(train)=1.85e-01, acc(train)=9.28e-01, error(valid)=1.55e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 5.6s to complete
#     error(train)=1.75e-01, acc(train)=9.31e-01, error(valid)=1.58e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 6.4s to complete
#     error(train)=1.76e-01, acc(train)=9.33e-01, error(valid)=1.67e+00, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 5.7s to complete
#     error(train)=1.85e-01, acc(train)=9.28e-01, error(valid)=1.59e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 6.4s to complete
#     error(train)=1.65e-01, acc(train)=9.33e-01, error(valid)=1.62e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 6.6s to complete
#     error(train)=1.71e-01, acc(train)=9.33e-01, error(valid)=1.68e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 5.5s to complete
#     error(train)=1.84e-01, acc(train)=9.28e-01, error(valid)=1.63e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 5.2s to complete
#     error(train)=1.89e-01, acc(train)=9.28e-01, error(valid)=1.67e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 5.9s to complete
#     error(train)=1.76e-01, acc(train)=9.32e-01, error(valid)=1.64e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 7.3s to complete
#     error(train)=1.53e-01, acc(train)=9.38e-01, error(valid)=1.62e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 6.5s to complete
#     error(train)=1.95e-01, acc(train)=9.24e-01, error(valid)=1.65e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 7.5s to complete
#     error(train)=1.67e-01, acc(train)=9.34e-01, error(valid)=1.66e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 6.2s to complete
#     error(train)=1.69e-01, acc(train)=9.34e-01, error(valid)=1.70e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 5.6s to complete
#     error(train)=1.53e-01, acc(train)=9.36e-01, error(valid)=1.65e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 5.9s to complete
#     error(train)=1.53e-01, acc(train)=9.37e-01, error(valid)=1.56e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 5.6s to complete
#     error(train)=1.76e-01, acc(train)=9.31e-01, error(valid)=1.70e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 7.2s to complete
#     error(train)=1.77e-01, acc(train)=9.30e-01, error(valid)=1.64e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 6.0s to complete
#     error(train)=1.55e-01, acc(train)=9.38e-01, error(valid)=1.69e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 6.5s to complete
#     error(train)=1.67e-01, acc(train)=9.34e-01, error(valid)=1.67e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 7.2s to complete
#     error(train)=1.61e-01, acc(train)=9.34e-01, error(valid)=1.72e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 6.1s to complete
#     error(train)=1.56e-01, acc(train)=9.37e-01, error(valid)=1.72e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 5.2s to complete
#     error(train)=1.71e-01, acc(train)=9.34e-01, error(valid)=1.72e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 5.9s to complete
#     error(train)=1.79e-01, acc(train)=9.29e-01, error(valid)=1.70e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 5.3s to complete
#     error(train)=1.78e-01, acc(train)=9.31e-01, error(valid)=1.75e+00, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 5.4s to complete
#     error(train)=1.49e-01, acc(train)=9.40e-01, error(valid)=1.71e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 5.3s to complete
#     error(train)=1.62e-01, acc(train)=9.36e-01, error(valid)=1.79e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 5.9s to complete
#     error(train)=1.65e-01, acc(train)=9.35e-01, error(valid)=1.80e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 7.4s to complete
#     error(train)=1.58e-01, acc(train)=9.36e-01, error(valid)=1.74e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 7.7s to complete
#     error(train)=1.59e-01, acc(train)=9.38e-01, error(valid)=1.80e+00, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 5.6s to complete
#     error(train)=1.52e-01, acc(train)=9.40e-01, error(valid)=1.77e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 5.3s to complete
#     error(train)=1.39e-01, acc(train)=9.44e-01, error(valid)=1.81e+00, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 5.6s to complete
#     error(train)=1.48e-01, acc(train)=9.40e-01, error(valid)=1.74e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 5.3s to complete
#     error(train)=1.59e-01, acc(train)=9.36e-01, error(valid)=1.72e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 5.1s to complete
#     error(train)=1.61e-01, acc(train)=9.38e-01, error(valid)=1.88e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 5.2s to complete
#     error(train)=1.72e-01, acc(train)=9.33e-01, error(valid)=1.84e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 5.1s to complete
#     error(train)=1.62e-01, acc(train)=9.37e-01, error(valid)=1.92e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 4.9s to complete
#     error(train)=1.49e-01, acc(train)=9.41e-01, error(valid)=1.84e+00, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 5.3s to complete
#     error(train)=1.35e-01, acc(train)=9.45e-01, error(valid)=1.87e+00, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 5.2s to complete
#     error(train)=1.44e-01, acc(train)=9.43e-01, error(valid)=1.91e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 4.8s to complete
#     error(train)=1.38e-01, acc(train)=9.44e-01, error(valid)=1.82e+00, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 6.2s to complete
#     error(train)=1.62e-01, acc(train)=9.36e-01, error(valid)=1.87e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 5.2s to complete
#     error(train)=1.41e-01, acc(train)=9.44e-01, error(valid)=1.87e+00, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 5.0s to complete
#     error(train)=1.36e-01, acc(train)=9.45e-01, error(valid)=1.83e+00, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 5.1s to complete
#     error(train)=1.37e-01, acc(train)=9.44e-01, error(valid)=1.84e+00, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 5.2s to complete
#     error(train)=1.35e-01, acc(train)=9.45e-01, error(valid)=1.79e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 5.0s to complete
#     error(train)=1.45e-01, acc(train)=9.41e-01, error(valid)=1.86e+00, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 5.0s to complete
#     error(train)=1.34e-01, acc(train)=9.45e-01, error(valid)=1.86e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 5.2s to complete
#     error(train)=1.48e-01, acc(train)=9.42e-01, error(valid)=1.91e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 5.0s to complete
#     error(train)=1.36e-01, acc(train)=9.45e-01, error(valid)=1.85e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 6.2s to complete
#     error(train)=1.56e-01, acc(train)=9.41e-01, error(valid)=1.93e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 6.1s to complete
#     error(train)=1.43e-01, acc(train)=9.43e-01, error(valid)=1.92e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 5.9s to complete
#     error(train)=1.30e-01, acc(train)=9.48e-01, error(valid)=1.91e+00, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 6.1s to complete
#     error(train)=1.47e-01, acc(train)=9.42e-01, error(valid)=1.97e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 5.4s to complete
#     error(train)=1.37e-01, acc(train)=9.45e-01, error(valid)=1.95e+00, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 5.6s to complete
#     error(train)=1.32e-01, acc(train)=9.45e-01, error(valid)=1.89e+00, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 5.6s to complete
#     error(train)=1.41e-01, acc(train)=9.44e-01, error(valid)=1.95e+00, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 6.6s to complete
#     error(train)=1.32e-01, acc(train)=9.47e-01, error(valid)=1.94e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 6.5s to complete
#     error(train)=1.36e-01, acc(train)=9.45e-01, error(valid)=1.96e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 6.7s to complete
#     error(train)=1.46e-01, acc(train)=9.43e-01, error(valid)=2.03e+00, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 5.3s to complete
#     error(train)=1.35e-01, acc(train)=9.46e-01, error(valid)=1.96e+00, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 5.5s to complete
#     error(train)=1.17e-01, acc(train)=9.51e-01, error(valid)=1.97e+00, acc(valid)=8.07e-01

# %% [markdown]
# # PartA 3.  In this experiment, I set the learning rate to 0.001. And I add a dropout Layer to prevent overfitting.

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer,DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule,RMSPropLearningRule,AdamLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
incl_prob = 0.5
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


model = MultipleLayerModel([
    DropoutLayer(rng, incl_prob),
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])



error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule_Gradient = GradientDescentLearningRule(learning_rate=learning_rate)
learning_rule_RMS = RMSPropLearningRule(learning_rate=learning_rate)
learning_rule_Adam = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('learning_rule_Gradient\n\n')
[stats_Gradient, keys_Gradient] = train_model_and_plot_stats(
    model, error, learning_rule_Gradient, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_RMS\n\n')
[stats_RMS, keys_RMS] = train_model_and_plot_stats(
    model, error, learning_rule_RMS, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('learning_rule_Adam\n\n')
[stats_Adam, keys_Adam] = train_model_and_plot_stats(
    model, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)



 # Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_1.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_1.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different learning rules(add dropout)in training dataset(learning rate is 0.001)')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartA3_learning_train_error_0001drop.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_2.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_2.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different learning rules(add dropout)in valid dataset(learning rate is 0.001) ')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('PartA3_learning_valid_error_0001drop.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_3.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_3.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')


ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different learning rules(add dropout)in training dataset(learning rate is 0.001) ')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartA3_learning_train_acc_0001drop.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_Gradient.shape[0]) * stats_interval,
            stats_Gradient[1:, keys_Gradient[k]], label='learning_rule_Gradient')
    ax_4.plot(np.arange(1, stats_RMS.shape[0]) * stats_interval,
            stats_RMS[1:, keys_RMS[k]], label='learning_rule_RMS')

    ax_4.plot(np.arange(1, stats_Adam.shape[0]) * stats_interval,
            stats_Adam[1:, keys_Adam[k]], label='learning_rule_Adam')

ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different learning rules(add dropout)in valid dataset(learning rate is 0.001) ')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartA3_learning_valid_acc_0001drop.pdf') # Save figure to current directory in PDF format
# Out:
# learning_rule_Gradient
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 6.9s to complete
#     error(train)=3.85e+00, acc(train)=2.22e-02, error(valid)=3.85e+00, acc(valid)=2.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 7.2s to complete
#     error(train)=3.85e+00, acc(train)=2.49e-02, error(valid)=3.85e+00, acc(valid)=2.37e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 7.0s to complete
#     error(train)=3.85e+00, acc(train)=2.71e-02, error(valid)=3.85e+00, acc(valid)=2.65e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 5.9s to complete
#     error(train)=3.85e+00, acc(train)=2.98e-02, error(valid)=3.85e+00, acc(valid)=3.01e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 6.4s to complete
#     error(train)=3.85e+00, acc(train)=3.24e-02, error(valid)=3.85e+00, acc(valid)=3.27e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 6.6s to complete
#     error(train)=3.85e+00, acc(train)=3.58e-02, error(valid)=3.85e+00, acc(valid)=3.46e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 8.3s to complete
#     error(train)=3.85e+00, acc(train)=3.91e-02, error(valid)=3.85e+00, acc(valid)=3.77e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 6.6s to complete
#     error(train)=3.84e+00, acc(train)=4.22e-02, error(valid)=3.84e+00, acc(valid)=4.06e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 5.8s to complete
#     error(train)=3.84e+00, acc(train)=4.50e-02, error(valid)=3.84e+00, acc(valid)=4.37e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.7s to complete
#     error(train)=3.84e+00, acc(train)=4.80e-02, error(valid)=3.84e+00, acc(valid)=4.69e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 5.4s to complete
#     error(train)=3.84e+00, acc(train)=5.09e-02, error(valid)=3.84e+00, acc(valid)=4.95e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 5.8s to complete
#     error(train)=3.84e+00, acc(train)=5.36e-02, error(valid)=3.84e+00, acc(valid)=5.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 5.3s to complete
#     error(train)=3.84e+00, acc(train)=5.66e-02, error(valid)=3.84e+00, acc(valid)=5.36e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 5.2s to complete
#     error(train)=3.84e+00, acc(train)=5.95e-02, error(valid)=3.84e+00, acc(valid)=5.61e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 5.1s to complete
#     error(train)=3.84e+00, acc(train)=6.22e-02, error(valid)=3.84e+00, acc(valid)=5.94e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 5.2s to complete
#     error(train)=3.84e+00, acc(train)=6.45e-02, error(valid)=3.84e+00, acc(valid)=6.06e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 5.2s to complete
#     error(train)=3.83e+00, acc(train)=6.71e-02, error(valid)=3.84e+00, acc(valid)=6.30e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 6.0s to complete
#     error(train)=3.83e+00, acc(train)=6.96e-02, error(valid)=3.83e+00, acc(valid)=6.53e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 6.1s to complete
#     error(train)=3.83e+00, acc(train)=7.17e-02, error(valid)=3.83e+00, acc(valid)=6.70e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 4.9s to complete
#     error(train)=3.83e+00, acc(train)=7.37e-02, error(valid)=3.83e+00, acc(valid)=6.88e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 4.8s to complete
#     error(train)=3.83e+00, acc(train)=7.59e-02, error(valid)=3.83e+00, acc(valid)=7.12e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 6.1s to complete
#     error(train)=3.83e+00, acc(train)=7.84e-02, error(valid)=3.83e+00, acc(valid)=7.34e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 5.5s to complete
#     error(train)=3.83e+00, acc(train)=8.06e-02, error(valid)=3.83e+00, acc(valid)=7.53e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 4.9s to complete
#     error(train)=3.83e+00, acc(train)=8.20e-02, error(valid)=3.83e+00, acc(valid)=7.65e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 5.2s to complete
#     error(train)=3.82e+00, acc(train)=8.38e-02, error(valid)=3.82e+00, acc(valid)=7.80e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 5.6s to complete
#     error(train)=3.82e+00, acc(train)=8.48e-02, error(valid)=3.82e+00, acc(valid)=7.80e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 5.4s to complete
#     error(train)=3.82e+00, acc(train)=8.65e-02, error(valid)=3.82e+00, acc(valid)=7.96e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 7.1s to complete
#     error(train)=3.82e+00, acc(train)=8.74e-02, error(valid)=3.82e+00, acc(valid)=8.09e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 5.8s to complete
#     error(train)=3.82e+00, acc(train)=8.88e-02, error(valid)=3.82e+00, acc(valid)=8.25e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 5.0s to complete
#     error(train)=3.81e+00, acc(train)=9.04e-02, error(valid)=3.82e+00, acc(valid)=8.36e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 5.5s to complete
#     error(train)=3.81e+00, acc(train)=9.22e-02, error(valid)=3.81e+00, acc(valid)=8.52e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 4.8s to complete
#     error(train)=3.81e+00, acc(train)=9.40e-02, error(valid)=3.81e+00, acc(valid)=8.62e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 4.9s to complete
#     error(train)=3.81e+00, acc(train)=9.56e-02, error(valid)=3.81e+00, acc(valid)=8.80e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 7.0s to complete
#     error(train)=3.80e+00, acc(train)=9.76e-02, error(valid)=3.81e+00, acc(valid)=8.91e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 6.2s to complete
#     error(train)=3.80e+00, acc(train)=9.94e-02, error(valid)=3.80e+00, acc(valid)=9.16e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 7.8s to complete
#     error(train)=3.80e+00, acc(train)=1.01e-01, error(valid)=3.80e+00, acc(valid)=9.26e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 7.5s to complete
#     error(train)=3.80e+00, acc(train)=1.03e-01, error(valid)=3.80e+00, acc(valid)=9.44e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 6.7s to complete
#     error(train)=3.79e+00, acc(train)=1.05e-01, error(valid)=3.79e+00, acc(valid)=9.62e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 7.8s to complete
#     error(train)=3.79e+00, acc(train)=1.06e-01, error(valid)=3.79e+00, acc(valid)=9.85e-02
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 10.9s to complete
#     error(train)=3.78e+00, acc(train)=1.08e-01, error(valid)=3.79e+00, acc(valid)=1.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 5.7s to complete
#     error(train)=3.78e+00, acc(train)=1.10e-01, error(valid)=3.78e+00, acc(valid)=1.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 5.5s to complete
#     error(train)=3.78e+00, acc(train)=1.12e-01, error(valid)=3.78e+00, acc(valid)=1.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 7.4s to complete
#     error(train)=3.77e+00, acc(train)=1.13e-01, error(valid)=3.77e+00, acc(valid)=1.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 4.3s to complete
#     error(train)=3.77e+00, acc(train)=1.15e-01, error(valid)=3.77e+00, acc(valid)=1.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 4.8s to complete
#     error(train)=3.76e+00, acc(train)=1.16e-01, error(valid)=3.76e+00, acc(valid)=1.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 5.1s to complete
#     error(train)=3.76e+00, acc(train)=1.18e-01, error(valid)=3.76e+00, acc(valid)=1.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 4.8s to complete
#     error(train)=3.75e+00, acc(train)=1.20e-01, error(valid)=3.75e+00, acc(valid)=1.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 4.7s to complete
#     error(train)=3.75e+00, acc(train)=1.22e-01, error(valid)=3.75e+00, acc(valid)=1.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 5.2s to complete
#     error(train)=3.74e+00, acc(train)=1.25e-01, error(valid)=3.74e+00, acc(valid)=1.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 5.5s to complete
#     error(train)=3.73e+00, acc(train)=1.27e-01, error(valid)=3.73e+00, acc(valid)=1.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 5.2s to complete
#     error(train)=3.73e+00, acc(train)=1.31e-01, error(valid)=3.73e+00, acc(valid)=1.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 4.8s to complete
#     error(train)=3.72e+00, acc(train)=1.34e-01, error(valid)=3.72e+00, acc(valid)=1.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 5.2s to complete
#     error(train)=3.71e+00, acc(train)=1.37e-01, error(valid)=3.71e+00, acc(valid)=1.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 4.5s to complete
#     error(train)=3.70e+00, acc(train)=1.40e-01, error(valid)=3.70e+00, acc(valid)=1.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 4.6s to complete
#     error(train)=3.70e+00, acc(train)=1.43e-01, error(valid)=3.70e+00, acc(valid)=1.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 5.1s to complete
#     error(train)=3.69e+00, acc(train)=1.47e-01, error(valid)=3.69e+00, acc(valid)=1.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 6.2s to complete
#     error(train)=3.68e+00, acc(train)=1.51e-01, error(valid)=3.68e+00, acc(valid)=1.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 7.3s to complete
#     error(train)=3.67e+00, acc(train)=1.54e-01, error(valid)=3.67e+00, acc(valid)=1.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 6.1s to complete
#     error(train)=3.66e+00, acc(train)=1.58e-01, error(valid)=3.66e+00, acc(valid)=1.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 6.1s to complete
#     error(train)=3.65e+00, acc(train)=1.62e-01, error(valid)=3.65e+00, acc(valid)=1.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 6.5s to complete
#     error(train)=3.64e+00, acc(train)=1.66e-01, error(valid)=3.64e+00, acc(valid)=1.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 6.4s to complete
#     error(train)=3.63e+00, acc(train)=1.70e-01, error(valid)=3.63e+00, acc(valid)=1.65e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 5.2s to complete
#     error(train)=3.61e+00, acc(train)=1.75e-01, error(valid)=3.61e+00, acc(valid)=1.71e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 5.4s to complete
#     error(train)=3.60e+00, acc(train)=1.79e-01, error(valid)=3.60e+00, acc(valid)=1.74e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 4.7s to complete
#     error(train)=3.59e+00, acc(train)=1.84e-01, error(valid)=3.59e+00, acc(valid)=1.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 4.9s to complete
#     error(train)=3.58e+00, acc(train)=1.90e-01, error(valid)=3.58e+00, acc(valid)=1.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 6.6s to complete
#     error(train)=3.56e+00, acc(train)=1.94e-01, error(valid)=3.56e+00, acc(valid)=1.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 5.3s to complete
#     error(train)=3.55e+00, acc(train)=2.00e-01, error(valid)=3.55e+00, acc(valid)=1.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 5.7s to complete
#     error(train)=3.53e+00, acc(train)=2.05e-01, error(valid)=3.53e+00, acc(valid)=2.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 5.3s to complete
#     error(train)=3.52e+00, acc(train)=2.10e-01, error(valid)=3.52e+00, acc(valid)=2.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 10.9s to complete
#     error(train)=3.50e+00, acc(train)=2.16e-01, error(valid)=3.50e+00, acc(valid)=2.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 6.7s to complete
#     error(train)=3.49e+00, acc(train)=2.20e-01, error(valid)=3.49e+00, acc(valid)=2.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 5.2s to complete
#     error(train)=3.47e+00, acc(train)=2.23e-01, error(valid)=3.47e+00, acc(valid)=2.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 6.0s to complete
#     error(train)=3.46e+00, acc(train)=2.26e-01, error(valid)=3.45e+00, acc(valid)=2.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 6.1s to complete
#     error(train)=3.44e+00, acc(train)=2.31e-01, error(valid)=3.44e+00, acc(valid)=2.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 7.0s to complete
#     error(train)=3.42e+00, acc(train)=2.36e-01, error(valid)=3.42e+00, acc(valid)=2.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 5.5s to complete
#     error(train)=3.40e+00, acc(train)=2.38e-01, error(valid)=3.40e+00, acc(valid)=2.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 5.5s to complete
#     error(train)=3.38e+00, acc(train)=2.42e-01, error(valid)=3.38e+00, acc(valid)=2.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 4.7s to complete
#     error(train)=3.37e+00, acc(train)=2.45e-01, error(valid)=3.36e+00, acc(valid)=2.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 6.6s to complete
#     error(train)=3.35e+00, acc(train)=2.49e-01, error(valid)=3.35e+00, acc(valid)=2.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 6.8s to complete
#     error(train)=3.33e+00, acc(train)=2.51e-01, error(valid)=3.33e+00, acc(valid)=2.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 8.4s to complete
#     error(train)=3.31e+00, acc(train)=2.55e-01, error(valid)=3.31e+00, acc(valid)=2.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 8.0s to complete
#     error(train)=3.29e+00, acc(train)=2.59e-01, error(valid)=3.29e+00, acc(valid)=2.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 6.8s to complete
#     error(train)=3.27e+00, acc(train)=2.63e-01, error(valid)=3.27e+00, acc(valid)=2.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 5.9s to complete
#     error(train)=3.25e+00, acc(train)=2.67e-01, error(valid)=3.25e+00, acc(valid)=2.66e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 5.8s to complete
#     error(train)=3.23e+00, acc(train)=2.71e-01, error(valid)=3.23e+00, acc(valid)=2.70e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 5.2s to complete
#     error(train)=3.21e+00, acc(train)=2.77e-01, error(valid)=3.21e+00, acc(valid)=2.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 4.4s to complete
#     error(train)=3.19e+00, acc(train)=2.79e-01, error(valid)=3.19e+00, acc(valid)=2.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 4.7s to complete
#     error(train)=3.18e+00, acc(train)=2.83e-01, error(valid)=3.17e+00, acc(valid)=2.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 4.3s to complete
#     error(train)=3.16e+00, acc(train)=2.86e-01, error(valid)=3.15e+00, acc(valid)=2.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 4.6s to complete
#     error(train)=3.14e+00, acc(train)=2.89e-01, error(valid)=3.14e+00, acc(valid)=2.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 4.5s to complete
#     error(train)=3.12e+00, acc(train)=2.92e-01, error(valid)=3.12e+00, acc(valid)=2.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 4.5s to complete
#     error(train)=3.10e+00, acc(train)=2.95e-01, error(valid)=3.10e+00, acc(valid)=2.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 4.3s to complete
#     error(train)=3.08e+00, acc(train)=2.99e-01, error(valid)=3.08e+00, acc(valid)=2.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 4.5s to complete
#     error(train)=3.06e+00, acc(train)=3.02e-01, error(valid)=3.06e+00, acc(valid)=2.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 4.5s to complete
#     error(train)=3.05e+00, acc(train)=3.05e-01, error(valid)=3.04e+00, acc(valid)=3.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 5.5s to complete
#     error(train)=3.03e+00, acc(train)=3.07e-01, error(valid)=3.03e+00, acc(valid)=3.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 5.6s to complete
#     error(train)=3.01e+00, acc(train)=3.11e-01, error(valid)=3.01e+00, acc(valid)=3.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 4.7s to complete
#     error(train)=3.00e+00, acc(train)=3.14e-01, error(valid)=2.99e+00, acc(valid)=3.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 4.6s to complete
#     error(train)=2.98e+00, acc(train)=3.17e-01, error(valid)=2.98e+00, acc(valid)=3.15e-01
# learning_rule_RMS
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 5.2s to complete
#     error(train)=1.84e+00, acc(train)=5.30e-01, error(valid)=1.84e+00, acc(valid)=5.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 5.4s to complete
#     error(train)=1.52e+00, acc(train)=5.89e-01, error(valid)=1.52e+00, acc(valid)=5.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 5.5s to complete
#     error(train)=1.34e+00, acc(train)=6.28e-01, error(valid)=1.35e+00, acc(valid)=6.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 5.5s to complete
#     error(train)=1.24e+00, acc(train)=6.52e-01, error(valid)=1.24e+00, acc(valid)=6.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 6.2s to complete
#     error(train)=1.17e+00, acc(train)=6.70e-01, error(valid)=1.18e+00, acc(valid)=6.69e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 5.7s to complete
#     error(train)=1.11e+00, acc(train)=6.76e-01, error(valid)=1.11e+00, acc(valid)=6.74e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 5.5s to complete
#     error(train)=1.06e+00, acc(train)=6.95e-01, error(valid)=1.07e+00, acc(valid)=6.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 7.2s to complete
#     error(train)=1.03e+00, acc(train)=7.05e-01, error(valid)=1.04e+00, acc(valid)=7.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 7.0s to complete
#     error(train)=1.02e+00, acc(train)=7.10e-01, error(valid)=1.02e+00, acc(valid)=7.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.5s to complete
#     error(train)=9.88e-01, acc(train)=7.15e-01, error(valid)=9.93e-01, acc(valid)=7.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 7.5s to complete
#     error(train)=9.61e-01, acc(train)=7.21e-01, error(valid)=9.63e-01, acc(valid)=7.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 7.9s to complete
#     error(train)=9.47e-01, acc(train)=7.23e-01, error(valid)=9.51e-01, acc(valid)=7.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 9.7s to complete
#     error(train)=9.31e-01, acc(train)=7.26e-01, error(valid)=9.34e-01, acc(valid)=7.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 11.3s to complete
#     error(train)=9.27e-01, acc(train)=7.31e-01, error(valid)=9.33e-01, acc(valid)=7.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 6.8s to complete
#     error(train)=9.25e-01, acc(train)=7.29e-01, error(valid)=9.28e-01, acc(valid)=7.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 6.8s to complete
#     error(train)=9.11e-01, acc(train)=7.29e-01, error(valid)=9.13e-01, acc(valid)=7.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 6.6s to complete
#     error(train)=8.92e-01, acc(train)=7.38e-01, error(valid)=8.95e-01, acc(valid)=7.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 6.2s to complete
#     error(train)=8.84e-01, acc(train)=7.40e-01, error(valid)=8.87e-01, acc(valid)=7.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 5.7s to complete
#     error(train)=8.81e-01, acc(train)=7.41e-01, error(valid)=8.86e-01, acc(valid)=7.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 7.0s to complete
#     error(train)=8.74e-01, acc(train)=7.43e-01, error(valid)=8.78e-01, acc(valid)=7.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 5.8s to complete
#     error(train)=8.76e-01, acc(train)=7.36e-01, error(valid)=8.83e-01, acc(valid)=7.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 5.9s to complete
#     error(train)=8.73e-01, acc(train)=7.42e-01, error(valid)=8.78e-01, acc(valid)=7.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 6.2s to complete
#     error(train)=8.50e-01, acc(train)=7.44e-01, error(valid)=8.55e-01, acc(valid)=7.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 6.0s to complete
#     error(train)=8.58e-01, acc(train)=7.45e-01, error(valid)=8.63e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 7.5s to complete
#     error(train)=8.48e-01, acc(train)=7.49e-01, error(valid)=8.54e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 13.2s to complete
#     error(train)=8.65e-01, acc(train)=7.47e-01, error(valid)=8.72e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 7.6s to complete
#     error(train)=8.58e-01, acc(train)=7.46e-01, error(valid)=8.65e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 7.5s to complete
#     error(train)=8.61e-01, acc(train)=7.48e-01, error(valid)=8.67e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 11.2s to complete
#     error(train)=8.39e-01, acc(train)=7.51e-01, error(valid)=8.45e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 7.1s to complete
#     error(train)=8.33e-01, acc(train)=7.52e-01, error(valid)=8.39e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 9.0s to complete
#     error(train)=8.45e-01, acc(train)=7.45e-01, error(valid)=8.51e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 8.9s to complete
#     error(train)=8.28e-01, acc(train)=7.55e-01, error(valid)=8.37e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 8.1s to complete
#     error(train)=8.35e-01, acc(train)=7.51e-01, error(valid)=8.43e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 7.7s to complete
#     error(train)=8.40e-01, acc(train)=7.49e-01, error(valid)=8.46e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 7.1s to complete
#     error(train)=8.34e-01, acc(train)=7.50e-01, error(valid)=8.37e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 8.5s to complete
#     error(train)=8.18e-01, acc(train)=7.52e-01, error(valid)=8.25e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 6.6s to complete
#     error(train)=8.39e-01, acc(train)=7.48e-01, error(valid)=8.46e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 6.3s to complete
#     error(train)=8.25e-01, acc(train)=7.52e-01, error(valid)=8.31e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 6.9s to complete
#     error(train)=8.34e-01, acc(train)=7.53e-01, error(valid)=8.41e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 7.3s to complete
#     error(train)=8.33e-01, acc(train)=7.51e-01, error(valid)=8.41e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 5.4s to complete
#     error(train)=8.39e-01, acc(train)=7.51e-01, error(valid)=8.47e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 5.6s to complete
#     error(train)=8.24e-01, acc(train)=7.51e-01, error(valid)=8.33e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 5.8s to complete
#     error(train)=8.35e-01, acc(train)=7.52e-01, error(valid)=8.45e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 7.3s to complete
#     error(train)=8.52e-01, acc(train)=7.53e-01, error(valid)=8.63e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 7.0s to complete
#     error(train)=8.26e-01, acc(train)=7.53e-01, error(valid)=8.34e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 7.4s to complete
#     error(train)=8.26e-01, acc(train)=7.54e-01, error(valid)=8.34e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 6.0s to complete
#     error(train)=8.35e-01, acc(train)=7.55e-01, error(valid)=8.45e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 6.4s to complete
#     error(train)=8.37e-01, acc(train)=7.52e-01, error(valid)=8.47e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 7.6s to complete
#     error(train)=8.27e-01, acc(train)=7.55e-01, error(valid)=8.38e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 7.0s to complete
#     error(train)=8.40e-01, acc(train)=7.49e-01, error(valid)=8.49e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 6.8s to complete
#     error(train)=8.45e-01, acc(train)=7.54e-01, error(valid)=8.57e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 6.0s to complete
#     error(train)=8.29e-01, acc(train)=7.57e-01, error(valid)=8.41e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 6.0s to complete
#     error(train)=8.36e-01, acc(train)=7.55e-01, error(valid)=8.47e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 6.6s to complete
#     error(train)=8.42e-01, acc(train)=7.52e-01, error(valid)=8.53e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 7.0s to complete
#     error(train)=8.59e-01, acc(train)=7.50e-01, error(valid)=8.69e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 6.8s to complete
#     error(train)=8.54e-01, acc(train)=7.55e-01, error(valid)=8.66e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 5.9s to complete
#     error(train)=8.53e-01, acc(train)=7.51e-01, error(valid)=8.64e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 6.2s to complete
#     error(train)=8.59e-01, acc(train)=7.49e-01, error(valid)=8.70e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 5.7s to complete
#     error(train)=8.31e-01, acc(train)=7.55e-01, error(valid)=8.41e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 6.5s to complete
#     error(train)=8.38e-01, acc(train)=7.55e-01, error(valid)=8.46e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 6.0s to complete
#     error(train)=8.59e-01, acc(train)=7.55e-01, error(valid)=8.69e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 7.5s to complete
#     error(train)=8.51e-01, acc(train)=7.51e-01, error(valid)=8.64e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 7.3s to complete
#     error(train)=8.51e-01, acc(train)=7.53e-01, error(valid)=8.64e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 7.7s to complete
#     error(train)=8.48e-01, acc(train)=7.52e-01, error(valid)=8.63e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 7.2s to complete
#     error(train)=8.35e-01, acc(train)=7.55e-01, error(valid)=8.46e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 7.2s to complete
#     error(train)=8.35e-01, acc(train)=7.53e-01, error(valid)=8.47e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 6.6s to complete
#     error(train)=8.82e-01, acc(train)=7.51e-01, error(valid)=8.96e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 6.9s to complete
#     error(train)=8.47e-01, acc(train)=7.50e-01, error(valid)=8.55e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 7.7s to complete
#     error(train)=8.54e-01, acc(train)=7.51e-01, error(valid)=8.64e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 7.0s to complete
#     error(train)=8.53e-01, acc(train)=7.52e-01, error(valid)=8.62e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 6.7s to complete
#     error(train)=8.52e-01, acc(train)=7.52e-01, error(valid)=8.60e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 7.5s to complete
#     error(train)=8.43e-01, acc(train)=7.51e-01, error(valid)=8.53e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 7.2s to complete
#     error(train)=8.65e-01, acc(train)=7.52e-01, error(valid)=8.76e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 6.9s to complete
#     error(train)=8.38e-01, acc(train)=7.51e-01, error(valid)=8.49e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 6.3s to complete
#     error(train)=8.60e-01, acc(train)=7.49e-01, error(valid)=8.70e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 7.0s to complete
#     error(train)=8.70e-01, acc(train)=7.46e-01, error(valid)=8.79e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 6.1s to complete
#     error(train)=8.58e-01, acc(train)=7.50e-01, error(valid)=8.70e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 6.1s to complete
#     error(train)=8.79e-01, acc(train)=7.44e-01, error(valid)=8.90e-01, acc(valid)=7.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 5.4s to complete
#     error(train)=8.69e-01, acc(train)=7.51e-01, error(valid)=8.80e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 5.9s to complete
#     error(train)=8.86e-01, acc(train)=7.46e-01, error(valid)=8.98e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 5.7s to complete
#     error(train)=8.63e-01, acc(train)=7.50e-01, error(valid)=8.71e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 6.5s to complete
#     error(train)=8.70e-01, acc(train)=7.47e-01, error(valid)=8.83e-01, acc(valid)=7.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 6.6s to complete
#     error(train)=8.64e-01, acc(train)=7.47e-01, error(valid)=8.76e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 6.4s to complete
#     error(train)=8.64e-01, acc(train)=7.50e-01, error(valid)=8.77e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 6.2s to complete
#     error(train)=8.81e-01, acc(train)=7.49e-01, error(valid)=8.93e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 6.5s to complete
#     error(train)=8.73e-01, acc(train)=7.44e-01, error(valid)=8.88e-01, acc(valid)=7.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 8.1s to complete
#     error(train)=8.89e-01, acc(train)=7.46e-01, error(valid)=9.04e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 6.7s to complete
#     error(train)=8.75e-01, acc(train)=7.48e-01, error(valid)=8.90e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 7.6s to complete
#     error(train)=8.71e-01, acc(train)=7.50e-01, error(valid)=8.84e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 6.4s to complete
#     error(train)=8.74e-01, acc(train)=7.48e-01, error(valid)=8.89e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 6.1s to complete
#     error(train)=8.62e-01, acc(train)=7.49e-01, error(valid)=8.76e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 7.5s to complete
#     error(train)=8.92e-01, acc(train)=7.45e-01, error(valid)=9.08e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 7.1s to complete
#     error(train)=8.69e-01, acc(train)=7.48e-01, error(valid)=8.83e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 6.4s to complete
#     error(train)=8.68e-01, acc(train)=7.48e-01, error(valid)=8.83e-01, acc(valid)=7.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 6.3s to complete
#     error(train)=8.67e-01, acc(train)=7.49e-01, error(valid)=8.79e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 6.6s to complete
#     error(train)=8.85e-01, acc(train)=7.44e-01, error(valid)=8.99e-01, acc(valid)=7.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 6.6s to complete
#     error(train)=8.70e-01, acc(train)=7.50e-01, error(valid)=8.85e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 5.4s to complete
#     error(train)=8.81e-01, acc(train)=7.45e-01, error(valid)=8.95e-01, acc(valid)=7.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 8.6s to complete
#     error(train)=8.74e-01, acc(train)=7.48e-01, error(valid)=8.90e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 6.8s to complete
#     error(train)=8.70e-01, acc(train)=7.46e-01, error(valid)=8.86e-01, acc(valid)=7.40e-01
# learning_rule_Adam
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 8.9s to complete
#     error(train)=9.76e-01, acc(train)=7.25e-01, error(valid)=9.84e-01, acc(valid)=7.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 7.3s to complete
#     error(train)=9.17e-01, acc(train)=7.38e-01, error(valid)=9.29e-01, acc(valid)=7.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 6.5s to complete
#     error(train)=9.20e-01, acc(train)=7.30e-01, error(valid)=9.34e-01, acc(valid)=7.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.8s to complete
#     error(train)=9.16e-01, acc(train)=7.39e-01, error(valid)=9.31e-01, acc(valid)=7.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 8.3s to complete
#     error(train)=9.03e-01, acc(train)=7.38e-01, error(valid)=9.15e-01, acc(valid)=7.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 6.1s to complete
#     error(train)=9.02e-01, acc(train)=7.43e-01, error(valid)=9.17e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 6.7s to complete
#     error(train)=8.90e-01, acc(train)=7.37e-01, error(valid)=9.06e-01, acc(valid)=7.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 6.4s to complete
#     error(train)=9.09e-01, acc(train)=7.40e-01, error(valid)=9.24e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 7.6s to complete
#     error(train)=8.75e-01, acc(train)=7.42e-01, error(valid)=8.89e-01, acc(valid)=7.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 7.7s to complete
#     error(train)=8.67e-01, acc(train)=7.45e-01, error(valid)=8.82e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 9.3s to complete
#     error(train)=8.75e-01, acc(train)=7.44e-01, error(valid)=8.90e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 8.1s to complete
#     error(train)=8.80e-01, acc(train)=7.46e-01, error(valid)=8.95e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 8.9s to complete
#     error(train)=8.74e-01, acc(train)=7.42e-01, error(valid)=8.89e-01, acc(valid)=7.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 6.8s to complete
#     error(train)=8.80e-01, acc(train)=7.44e-01, error(valid)=8.96e-01, acc(valid)=7.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 7.9s to complete
#     error(train)=8.86e-01, acc(train)=7.43e-01, error(valid)=9.00e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 9.3s to complete
#     error(train)=8.66e-01, acc(train)=7.43e-01, error(valid)=8.79e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 8.4s to complete
#     error(train)=8.76e-01, acc(train)=7.42e-01, error(valid)=8.94e-01, acc(valid)=7.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 8.9s to complete
#     error(train)=8.74e-01, acc(train)=7.45e-01, error(valid)=8.92e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 8.2s to complete
#     error(train)=8.47e-01, acc(train)=7.47e-01, error(valid)=8.68e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 7.0s to complete
#     error(train)=8.57e-01, acc(train)=7.40e-01, error(valid)=8.73e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 9.4s to complete
#     error(train)=8.71e-01, acc(train)=7.46e-01, error(valid)=8.86e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 10.2s to complete
#     error(train)=8.52e-01, acc(train)=7.49e-01, error(valid)=8.69e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 8.9s to complete
#     error(train)=8.35e-01, acc(train)=7.49e-01, error(valid)=8.52e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 10.0s to complete
#     error(train)=8.46e-01, acc(train)=7.46e-01, error(valid)=8.63e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 7.9s to complete
#     error(train)=8.55e-01, acc(train)=7.50e-01, error(valid)=8.71e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 7.3s to complete
#     error(train)=8.45e-01, acc(train)=7.50e-01, error(valid)=8.63e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 7.0s to complete
#     error(train)=8.43e-01, acc(train)=7.50e-01, error(valid)=8.60e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 7.8s to complete
#     error(train)=8.63e-01, acc(train)=7.47e-01, error(valid)=8.81e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 8.0s to complete
#     error(train)=8.33e-01, acc(train)=7.49e-01, error(valid)=8.48e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 8.8s to complete
#     error(train)=8.37e-01, acc(train)=7.48e-01, error(valid)=8.54e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 10.2s to complete
#     error(train)=8.26e-01, acc(train)=7.50e-01, error(valid)=8.43e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 8.7s to complete
#     error(train)=8.41e-01, acc(train)=7.51e-01, error(valid)=8.56e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 8.1s to complete
#     error(train)=8.34e-01, acc(train)=7.51e-01, error(valid)=8.51e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 8.5s to complete
#     error(train)=8.40e-01, acc(train)=7.49e-01, error(valid)=8.55e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 8.4s to complete
#     error(train)=8.49e-01, acc(train)=7.50e-01, error(valid)=8.66e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 8.6s to complete
#     error(train)=8.15e-01, acc(train)=7.51e-01, error(valid)=8.33e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 8.2s to complete
#     error(train)=8.16e-01, acc(train)=7.52e-01, error(valid)=8.34e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 8.3s to complete
#     error(train)=8.34e-01, acc(train)=7.50e-01, error(valid)=8.51e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 8.4s to complete
#     error(train)=8.33e-01, acc(train)=7.54e-01, error(valid)=8.49e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 7.5s to complete
#     error(train)=8.19e-01, acc(train)=7.54e-01, error(valid)=8.37e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 10.0s to complete
#     error(train)=8.46e-01, acc(train)=7.50e-01, error(valid)=8.62e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 7.9s to complete
#     error(train)=8.28e-01, acc(train)=7.54e-01, error(valid)=8.45e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 7.5s to complete
#     error(train)=8.26e-01, acc(train)=7.52e-01, error(valid)=8.42e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 8.2s to complete
#     error(train)=8.18e-01, acc(train)=7.53e-01, error(valid)=8.36e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 10.0s to complete
#     error(train)=8.18e-01, acc(train)=7.50e-01, error(valid)=8.37e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 10.1s to complete
#     error(train)=8.45e-01, acc(train)=7.50e-01, error(valid)=8.63e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 8.3s to complete
#     error(train)=8.33e-01, acc(train)=7.54e-01, error(valid)=8.49e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 11.2s to complete
#     error(train)=8.31e-01, acc(train)=7.52e-01, error(valid)=8.48e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 8.3s to complete
#     error(train)=8.29e-01, acc(train)=7.52e-01, error(valid)=8.45e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 9.0s to complete
#     error(train)=8.36e-01, acc(train)=7.51e-01, error(valid)=8.53e-01, acc(valid)=7.46e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 8.5s to complete
#     error(train)=8.24e-01, acc(train)=7.54e-01, error(valid)=8.40e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 8.4s to complete
#     error(train)=8.23e-01, acc(train)=7.55e-01, error(valid)=8.42e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 8.1s to complete
#     error(train)=8.16e-01, acc(train)=7.55e-01, error(valid)=8.36e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 9.1s to complete
#     error(train)=8.10e-01, acc(train)=7.56e-01, error(valid)=8.27e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 7.1s to complete
#     error(train)=8.25e-01, acc(train)=7.55e-01, error(valid)=8.46e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 6.5s to complete
#     error(train)=8.16e-01, acc(train)=7.49e-01, error(valid)=8.35e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 6.8s to complete
#     error(train)=8.27e-01, acc(train)=7.54e-01, error(valid)=8.48e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 7.6s to complete
#     error(train)=8.25e-01, acc(train)=7.52e-01, error(valid)=8.46e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 7.2s to complete
#     error(train)=8.09e-01, acc(train)=7.53e-01, error(valid)=8.26e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 7.3s to complete
#     error(train)=8.07e-01, acc(train)=7.56e-01, error(valid)=8.24e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 7.0s to complete
#     error(train)=8.09e-01, acc(train)=7.52e-01, error(valid)=8.28e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 6.8s to complete
#     error(train)=8.25e-01, acc(train)=7.53e-01, error(valid)=8.41e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 7.2s to complete
#     error(train)=8.19e-01, acc(train)=7.55e-01, error(valid)=8.40e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 7.5s to complete
#     error(train)=8.25e-01, acc(train)=7.56e-01, error(valid)=8.43e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 6.3s to complete
#     error(train)=8.25e-01, acc(train)=7.55e-01, error(valid)=8.44e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 6.8s to complete
#     error(train)=8.19e-01, acc(train)=7.55e-01, error(valid)=8.37e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 7.3s to complete
#     error(train)=8.12e-01, acc(train)=7.57e-01, error(valid)=8.30e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 6.2s to complete
#     error(train)=8.15e-01, acc(train)=7.54e-01, error(valid)=8.35e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 6.5s to complete
#     error(train)=8.14e-01, acc(train)=7.56e-01, error(valid)=8.33e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 7.1s to complete
#     error(train)=8.11e-01, acc(train)=7.57e-01, error(valid)=8.29e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 7.5s to complete
#     error(train)=8.26e-01, acc(train)=7.54e-01, error(valid)=8.42e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 6.5s to complete
#     error(train)=8.06e-01, acc(train)=7.55e-01, error(valid)=8.24e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 7.2s to complete
#     error(train)=8.14e-01, acc(train)=7.54e-01, error(valid)=8.31e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 7.5s to complete
#     error(train)=8.02e-01, acc(train)=7.53e-01, error(valid)=8.21e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 7.2s to complete
#     error(train)=8.01e-01, acc(train)=7.58e-01, error(valid)=8.20e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 6.6s to complete
#     error(train)=8.18e-01, acc(train)=7.54e-01, error(valid)=8.39e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 7.0s to complete
#     error(train)=8.18e-01, acc(train)=7.56e-01, error(valid)=8.38e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 6.4s to complete
#     error(train)=8.14e-01, acc(train)=7.58e-01, error(valid)=8.34e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 6.4s to complete
#     error(train)=8.07e-01, acc(train)=7.58e-01, error(valid)=8.26e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 6.7s to complete
#     error(train)=8.20e-01, acc(train)=7.55e-01, error(valid)=8.41e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 7.2s to complete
#     error(train)=7.99e-01, acc(train)=7.57e-01, error(valid)=8.19e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 7.1s to complete
#     error(train)=7.96e-01, acc(train)=7.58e-01, error(valid)=8.13e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 6.7s to complete
#     error(train)=8.15e-01, acc(train)=7.56e-01, error(valid)=8.34e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 6.0s to complete
#     error(train)=8.01e-01, acc(train)=7.58e-01, error(valid)=8.22e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 7.0s to complete
#     error(train)=8.10e-01, acc(train)=7.56e-01, error(valid)=8.28e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 7.8s to complete
#     error(train)=8.02e-01, acc(train)=7.58e-01, error(valid)=8.20e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 6.7s to complete
#     error(train)=8.14e-01, acc(train)=7.56e-01, error(valid)=8.34e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 7.0s to complete
#     error(train)=8.08e-01, acc(train)=7.58e-01, error(valid)=8.28e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 7.5s to complete
#     error(train)=8.00e-01, acc(train)=7.60e-01, error(valid)=8.21e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 9.1s to complete
#     error(train)=8.00e-01, acc(train)=7.59e-01, error(valid)=8.21e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 6.9s to complete
#     error(train)=8.05e-01, acc(train)=7.59e-01, error(valid)=8.25e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 7.4s to complete
#     error(train)=7.98e-01, acc(train)=7.60e-01, error(valid)=8.19e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 6.7s to complete
#     error(train)=8.02e-01, acc(train)=7.56e-01, error(valid)=8.22e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 7.4s to complete
#     error(train)=8.00e-01, acc(train)=7.58e-01, error(valid)=8.21e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 6.9s to complete
#     error(train)=8.05e-01, acc(train)=7.58e-01, error(valid)=8.24e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 6.8s to complete
#     error(train)=7.99e-01, acc(train)=7.60e-01, error(valid)=8.20e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 7.6s to complete
#     error(train)=7.95e-01, acc(train)=7.60e-01, error(valid)=8.14e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 7.8s to complete
#     error(train)=7.99e-01, acc(train)=7.56e-01, error(valid)=8.18e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 7.4s to complete
#     error(train)=7.97e-01, acc(train)=7.59e-01, error(valid)=8.16e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 7.6s to complete
#     error(train)=7.91e-01, acc(train)=7.59e-01, error(valid)=8.10e-01, acc(valid)=7.57e-01

# %% [markdown]
# ## PartA 7. Perform experiments on EMNIST Balanced to investigate the impact of using batch normalisation in deep neural networks, building on your earlier experiments.

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule,RMSPropLearningRule,AdamLearningRule
from mlp.optimisers import Optimiser
from mlp.layers import BatchNormalizationLayer
#setup hyperparameters
incl_prob = 0.5
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


model = MultipleLayerModel([
    DropoutLayer(rng, incl_prob),
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_BatchNormalizationLayer = MultipleLayerModel([
    DropoutLayer(rng, incl_prob),
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    BatchNormalizationLayer(hidden_dim),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    BatchNormalizationLayer(hidden_dim),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])



error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule_Adam = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('NoBatchNormalization_rule_Adam\n\n')
[stats, keys] = train_model_and_plot_stats(
    model, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('BatchNormalization_rule_Adam\n\n')
[stats_BatchNormalization, keys_BatchNormalization] = train_model_and_plot_stats(
    model_BatchNormalizationLayer, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)


# Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval,
            stats[1:, keys[k]], label='No-BatchNormalization')
    ax_1.plot(np.arange(1, stats_BatchNormalization.shape[0]) * stats_interval,
            stats_BatchNormalization[1:, keys_BatchNormalization[k]], label='BatchNormalization')


ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different BatchNormalizations in the training dataset ')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartA7_BatchNormalizations_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval,
            stats[1:, keys[k]], label='No-BatchNormalization')
    ax_2.plot(np.arange(1, stats_BatchNormalization.shape[0]) * stats_interval,
            stats_BatchNormalization[1:, keys_BatchNormalization[k]], label='BatchNormalization')



ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different BatchNormalizations in the valid dataset')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('PartA7_BatchNormalizations_valid_error.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats.shape[0]) * stats_interval,
            stats[1:, keys[k]], label='No-BatchNormalization')
    ax_3.plot(np.arange(1, stats_BatchNormalization.shape[0]) * stats_interval,
            stats_BatchNormalization[1:, keys_BatchNormalization[k]], label='BatchNormalization')



ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different BatchNormalizations in the training dataset ')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartA7_BatchNormalizations_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats.shape[0]) * stats_interval,
            stats[1:, keys[k]], label='No-BatchNormalization')
    ax_4.plot(np.arange(1, stats_BatchNormalization.shape[0]) * stats_interval,
            stats_BatchNormalization[1:, keys_BatchNormalization[k]], label='BatchNormalization')


ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different BatchNormalizations in the valid dataset ')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartA7_BatchNormalizations_valid_acc.pdf') # Save figure to current directory in PDF format
# Out:
# NoBatchNormalization_rule_Adam
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 7.5s to complete
#     error(train)=1.49e+00, acc(train)=5.99e-01, error(valid)=1.49e+00, acc(valid)=5.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 9.2s to complete
#     error(train)=1.31e+00, acc(train)=6.45e-01, error(valid)=1.32e+00, acc(valid)=6.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 16.3s to complete
#     error(train)=1.21e+00, acc(train)=6.68e-01, error(valid)=1.22e+00, acc(valid)=6.66e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 7.6s to complete
#     error(train)=1.14e+00, acc(train)=6.78e-01, error(valid)=1.15e+00, acc(valid)=6.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 7.3s to complete
#     error(train)=1.08e+00, acc(train)=6.91e-01, error(valid)=1.09e+00, acc(valid)=6.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 5.9s to complete
#     error(train)=1.04e+00, acc(train)=6.98e-01, error(valid)=1.05e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 6.1s to complete
#     error(train)=1.02e+00, acc(train)=7.02e-01, error(valid)=1.03e+00, acc(valid)=7.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 6.2s to complete
#     error(train)=9.84e-01, acc(train)=7.10e-01, error(valid)=9.93e-01, acc(valid)=7.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 6.1s to complete
#     error(train)=9.73e-01, acc(train)=7.20e-01, error(valid)=9.81e-01, acc(valid)=7.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.8s to complete
#     error(train)=9.41e-01, acc(train)=7.22e-01, error(valid)=9.49e-01, acc(valid)=7.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 6.1s to complete
#     error(train)=9.37e-01, acc(train)=7.26e-01, error(valid)=9.45e-01, acc(valid)=7.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 6.3s to complete
#     error(train)=9.22e-01, acc(train)=7.21e-01, error(valid)=9.33e-01, acc(valid)=7.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 6.2s to complete
#     error(train)=9.12e-01, acc(train)=7.29e-01, error(valid)=9.21e-01, acc(valid)=7.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 5.9s to complete
#     error(train)=8.95e-01, acc(train)=7.31e-01, error(valid)=9.05e-01, acc(valid)=7.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 5.8s to complete
#     error(train)=8.90e-01, acc(train)=7.34e-01, error(valid)=9.00e-01, acc(valid)=7.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 6.3s to complete
#     error(train)=8.78e-01, acc(train)=7.36e-01, error(valid)=8.87e-01, acc(valid)=7.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 6.1s to complete
#     error(train)=8.70e-01, acc(train)=7.36e-01, error(valid)=8.81e-01, acc(valid)=7.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 5.9s to complete
#     error(train)=8.60e-01, acc(train)=7.40e-01, error(valid)=8.70e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 8.9s to complete
#     error(train)=8.49e-01, acc(train)=7.40e-01, error(valid)=8.59e-01, acc(valid)=7.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 7.8s to complete
#     error(train)=8.64e-01, acc(train)=7.39e-01, error(valid)=8.75e-01, acc(valid)=7.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 6.4s to complete
#     error(train)=8.51e-01, acc(train)=7.44e-01, error(valid)=8.62e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 7.4s to complete
#     error(train)=8.42e-01, acc(train)=7.44e-01, error(valid)=8.53e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 8.4s to complete
#     error(train)=8.29e-01, acc(train)=7.47e-01, error(valid)=8.40e-01, acc(valid)=7.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 6.4s to complete
#     error(train)=8.27e-01, acc(train)=7.48e-01, error(valid)=8.39e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 10.4s to complete
#     error(train)=8.33e-01, acc(train)=7.51e-01, error(valid)=8.45e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 6.8s to complete
#     error(train)=8.30e-01, acc(train)=7.43e-01, error(valid)=8.45e-01, acc(valid)=7.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 9.2s to complete
#     error(train)=8.18e-01, acc(train)=7.47e-01, error(valid)=8.31e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 8.4s to complete
#     error(train)=8.13e-01, acc(train)=7.47e-01, error(valid)=8.27e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 8.5s to complete
#     error(train)=8.08e-01, acc(train)=7.52e-01, error(valid)=8.22e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 6.3s to complete
#     error(train)=8.10e-01, acc(train)=7.52e-01, error(valid)=8.23e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 6.3s to complete
#     error(train)=8.08e-01, acc(train)=7.55e-01, error(valid)=8.20e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 6.2s to complete
#     error(train)=8.11e-01, acc(train)=7.53e-01, error(valid)=8.25e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 6.0s to complete
#     error(train)=8.03e-01, acc(train)=7.53e-01, error(valid)=8.17e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 5.7s to complete
#     error(train)=8.01e-01, acc(train)=7.54e-01, error(valid)=8.16e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 5.8s to complete
#     error(train)=8.01e-01, acc(train)=7.55e-01, error(valid)=8.14e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 5.9s to complete
#     error(train)=7.93e-01, acc(train)=7.58e-01, error(valid)=8.09e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 5.8s to complete
#     error(train)=7.97e-01, acc(train)=7.54e-01, error(valid)=8.12e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 5.8s to complete
#     error(train)=7.93e-01, acc(train)=7.60e-01, error(valid)=8.08e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 6.9s to complete
#     error(train)=7.90e-01, acc(train)=7.60e-01, error(valid)=8.05e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 5.7s to complete
#     error(train)=7.86e-01, acc(train)=7.59e-01, error(valid)=8.04e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 5.8s to complete
#     error(train)=7.91e-01, acc(train)=7.57e-01, error(valid)=8.08e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 5.9s to complete
#     error(train)=7.87e-01, acc(train)=7.57e-01, error(valid)=8.03e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 5.9s to complete
#     error(train)=7.88e-01, acc(train)=7.54e-01, error(valid)=8.02e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 5.6s to complete
#     error(train)=7.74e-01, acc(train)=7.62e-01, error(valid)=7.89e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 5.8s to complete
#     error(train)=7.76e-01, acc(train)=7.58e-01, error(valid)=7.92e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 6.8s to complete
#     error(train)=7.89e-01, acc(train)=7.61e-01, error(valid)=8.04e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 8.2s to complete
#     error(train)=7.79e-01, acc(train)=7.56e-01, error(valid)=7.95e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 6.2s to complete
#     error(train)=7.83e-01, acc(train)=7.60e-01, error(valid)=7.98e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 5.8s to complete
#     error(train)=7.78e-01, acc(train)=7.62e-01, error(valid)=7.94e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 6.0s to complete
#     error(train)=7.83e-01, acc(train)=7.58e-01, error(valid)=7.99e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 5.9s to complete
#     error(train)=7.76e-01, acc(train)=7.58e-01, error(valid)=7.91e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 5.7s to complete
#     error(train)=7.71e-01, acc(train)=7.60e-01, error(valid)=7.87e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 5.9s to complete
#     error(train)=7.71e-01, acc(train)=7.60e-01, error(valid)=7.88e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 5.9s to complete
#     error(train)=7.73e-01, acc(train)=7.61e-01, error(valid)=7.90e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 6.2s to complete
#     error(train)=7.79e-01, acc(train)=7.57e-01, error(valid)=7.95e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 5.8s to complete
#     error(train)=7.69e-01, acc(train)=7.65e-01, error(valid)=7.86e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 5.7s to complete
#     error(train)=7.68e-01, acc(train)=7.59e-01, error(valid)=7.85e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 6.0s to complete
#     error(train)=7.69e-01, acc(train)=7.64e-01, error(valid)=7.86e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 6.3s to complete
#     error(train)=7.63e-01, acc(train)=7.64e-01, error(valid)=7.80e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 7.3s to complete
#     error(train)=7.66e-01, acc(train)=7.59e-01, error(valid)=7.81e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 6.3s to complete
#     error(train)=7.68e-01, acc(train)=7.63e-01, error(valid)=7.83e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 7.2s to complete
#     error(train)=7.68e-01, acc(train)=7.63e-01, error(valid)=7.86e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 5.8s to complete
#     error(train)=7.62e-01, acc(train)=7.65e-01, error(valid)=7.79e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 6.2s to complete
#     error(train)=7.70e-01, acc(train)=7.58e-01, error(valid)=7.87e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 6.0s to complete
#     error(train)=7.57e-01, acc(train)=7.63e-01, error(valid)=7.74e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 5.9s to complete
#     error(train)=7.60e-01, acc(train)=7.66e-01, error(valid)=7.76e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 6.2s to complete
#     error(train)=7.62e-01, acc(train)=7.62e-01, error(valid)=7.78e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 6.4s to complete
#     error(train)=7.63e-01, acc(train)=7.65e-01, error(valid)=7.79e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 6.6s to complete
#     error(train)=7.62e-01, acc(train)=7.67e-01, error(valid)=7.78e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 7.3s to complete
#     error(train)=7.61e-01, acc(train)=7.66e-01, error(valid)=7.78e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 7.4s to complete
#     error(train)=7.62e-01, acc(train)=7.68e-01, error(valid)=7.78e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 7.2s to complete
#     error(train)=7.71e-01, acc(train)=7.62e-01, error(valid)=7.89e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 7.0s to complete
#     error(train)=7.57e-01, acc(train)=7.67e-01, error(valid)=7.75e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 6.2s to complete
#     error(train)=7.59e-01, acc(train)=7.67e-01, error(valid)=7.77e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 6.2s to complete
#     error(train)=7.63e-01, acc(train)=7.66e-01, error(valid)=7.80e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 7.6s to complete
#     error(train)=7.53e-01, acc(train)=7.67e-01, error(valid)=7.70e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 8.5s to complete
#     error(train)=7.56e-01, acc(train)=7.66e-01, error(valid)=7.75e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 7.1s to complete
#     error(train)=7.61e-01, acc(train)=7.65e-01, error(valid)=7.79e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 7.6s to complete
#     error(train)=7.56e-01, acc(train)=7.67e-01, error(valid)=7.73e-01, acc(valid)=7.63e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 6.7s to complete
#     error(train)=7.59e-01, acc(train)=7.66e-01, error(valid)=7.76e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 6.7s to complete
#     error(train)=7.53e-01, acc(train)=7.66e-01, error(valid)=7.70e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 7.5s to complete
#     error(train)=7.57e-01, acc(train)=7.66e-01, error(valid)=7.74e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 8.1s to complete
#     error(train)=7.49e-01, acc(train)=7.69e-01, error(valid)=7.65e-01, acc(valid)=7.63e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 7.9s to complete
#     error(train)=7.63e-01, acc(train)=7.67e-01, error(valid)=7.81e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 6.3s to complete
#     error(train)=7.50e-01, acc(train)=7.68e-01, error(valid)=7.68e-01, acc(valid)=7.65e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 6.3s to complete
#     error(train)=7.55e-01, acc(train)=7.65e-01, error(valid)=7.73e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 8.9s to complete
#     error(train)=7.55e-01, acc(train)=7.66e-01, error(valid)=7.73e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 6.4s to complete
#     error(train)=7.58e-01, acc(train)=7.66e-01, error(valid)=7.76e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 7.7s to complete
#     error(train)=7.46e-01, acc(train)=7.71e-01, error(valid)=7.65e-01, acc(valid)=7.64e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 7.3s to complete
#     error(train)=7.54e-01, acc(train)=7.70e-01, error(valid)=7.69e-01, acc(valid)=7.65e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 6.8s to complete
#     error(train)=7.56e-01, acc(train)=7.63e-01, error(valid)=7.75e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 6.8s to complete
#     error(train)=7.41e-01, acc(train)=7.70e-01, error(valid)=7.59e-01, acc(valid)=7.64e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 6.9s to complete
#     error(train)=7.52e-01, acc(train)=7.66e-01, error(valid)=7.71e-01, acc(valid)=7.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 6.5s to complete
#     error(train)=7.52e-01, acc(train)=7.66e-01, error(valid)=7.69e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 6.4s to complete
#     error(train)=7.53e-01, acc(train)=7.67e-01, error(valid)=7.68e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 6.4s to complete
#     error(train)=7.49e-01, acc(train)=7.67e-01, error(valid)=7.67e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 6.5s to complete
#     error(train)=7.55e-01, acc(train)=7.69e-01, error(valid)=7.70e-01, acc(valid)=7.64e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 6.3s to complete
#     error(train)=7.44e-01, acc(train)=7.68e-01, error(valid)=7.59e-01, acc(valid)=7.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 7.3s to complete
#     error(train)=7.54e-01, acc(train)=7.69e-01, error(valid)=7.71e-01, acc(valid)=7.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 6.6s to complete
#     error(train)=7.46e-01, acc(train)=7.69e-01, error(valid)=7.63e-01, acc(valid)=7.63e-01
# BatchNormalization_rule_Adam
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 7.2s to complete
#     error(train)=1.42e+00, acc(train)=6.15e-01, error(valid)=1.43e+00, acc(valid)=6.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 7.4s to complete
#     error(train)=1.24e+00, acc(train)=6.51e-01, error(valid)=1.24e+00, acc(valid)=6.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 7.4s to complete
#     error(train)=1.15e+00, acc(train)=6.69e-01, error(valid)=1.15e+00, acc(valid)=6.65e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 7.3s to complete
#     error(train)=1.10e+00, acc(train)=6.81e-01, error(valid)=1.10e+00, acc(valid)=6.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 8.7s to complete
#     error(train)=1.04e+00, acc(train)=6.95e-01, error(valid)=1.05e+00, acc(valid)=6.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 8.7s to complete
#     error(train)=1.02e+00, acc(train)=6.99e-01, error(valid)=1.02e+00, acc(valid)=6.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 7.6s to complete
#     error(train)=9.82e-01, acc(train)=7.04e-01, error(valid)=9.85e-01, acc(valid)=7.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 7.9s to complete
#     error(train)=9.63e-01, acc(train)=7.13e-01, error(valid)=9.71e-01, acc(valid)=7.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 8.4s to complete
#     error(train)=9.52e-01, acc(train)=7.13e-01, error(valid)=9.62e-01, acc(valid)=7.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 8.7s to complete
#     error(train)=9.29e-01, acc(train)=7.22e-01, error(valid)=9.38e-01, acc(valid)=7.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 8.0s to complete
#     error(train)=9.23e-01, acc(train)=7.22e-01, error(valid)=9.27e-01, acc(valid)=7.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 8.1s to complete
#     error(train)=9.13e-01, acc(train)=7.24e-01, error(valid)=9.16e-01, acc(valid)=7.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 7.9s to complete
#     error(train)=8.99e-01, acc(train)=7.24e-01, error(valid)=9.07e-01, acc(valid)=7.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 7.2s to complete
#     error(train)=8.90e-01, acc(train)=7.27e-01, error(valid)=9.02e-01, acc(valid)=7.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 8.2s to complete
#     error(train)=8.86e-01, acc(train)=7.25e-01, error(valid)=8.93e-01, acc(valid)=7.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 7.4s to complete
#     error(train)=8.71e-01, acc(train)=7.35e-01, error(valid)=8.82e-01, acc(valid)=7.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 7.9s to complete
#     error(train)=8.64e-01, acc(train)=7.37e-01, error(valid)=8.75e-01, acc(valid)=7.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 9.2s to complete
#     error(train)=8.62e-01, acc(train)=7.36e-01, error(valid)=8.71e-01, acc(valid)=7.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 8.4s to complete
#     error(train)=8.55e-01, acc(train)=7.40e-01, error(valid)=8.66e-01, acc(valid)=7.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 8.5s to complete
#     error(train)=8.56e-01, acc(train)=7.37e-01, error(valid)=8.64e-01, acc(valid)=7.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 8.2s to complete
#     error(train)=8.48e-01, acc(train)=7.40e-01, error(valid)=8.60e-01, acc(valid)=7.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 10.3s to complete
#     error(train)=8.43e-01, acc(train)=7.40e-01, error(valid)=8.52e-01, acc(valid)=7.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 7.9s to complete
#     error(train)=8.43e-01, acc(train)=7.43e-01, error(valid)=8.50e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 7.6s to complete
#     error(train)=8.35e-01, acc(train)=7.44e-01, error(valid)=8.43e-01, acc(valid)=7.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 9.1s to complete
#     error(train)=8.26e-01, acc(train)=7.45e-01, error(valid)=8.36e-01, acc(valid)=7.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 9.1s to complete
#     error(train)=8.24e-01, acc(train)=7.46e-01, error(valid)=8.34e-01, acc(valid)=7.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 10.1s to complete
#     error(train)=8.24e-01, acc(train)=7.45e-01, error(valid)=8.34e-01, acc(valid)=7.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 8.9s to complete
#     error(train)=8.25e-01, acc(train)=7.45e-01, error(valid)=8.30e-01, acc(valid)=7.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 9.8s to complete
#     error(train)=8.15e-01, acc(train)=7.49e-01, error(valid)=8.18e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 8.9s to complete
#     error(train)=8.15e-01, acc(train)=7.49e-01, error(valid)=8.25e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 7.8s to complete
#     error(train)=8.13e-01, acc(train)=7.49e-01, error(valid)=8.21e-01, acc(valid)=7.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 7.9s to complete
#     error(train)=8.07e-01, acc(train)=7.49e-01, error(valid)=8.15e-01, acc(valid)=7.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 9.4s to complete
#     error(train)=8.07e-01, acc(train)=7.47e-01, error(valid)=8.13e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 7.4s to complete
#     error(train)=8.08e-01, acc(train)=7.49e-01, error(valid)=8.18e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 8.5s to complete
#     error(train)=8.08e-01, acc(train)=7.48e-01, error(valid)=8.16e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 11.4s to complete
#     error(train)=8.03e-01, acc(train)=7.51e-01, error(valid)=8.08e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 8.1s to complete
#     error(train)=7.93e-01, acc(train)=7.54e-01, error(valid)=7.99e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 9.2s to complete
#     error(train)=7.98e-01, acc(train)=7.52e-01, error(valid)=8.05e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 10.7s to complete
#     error(train)=7.95e-01, acc(train)=7.53e-01, error(valid)=8.04e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 8.3s to complete
#     error(train)=7.91e-01, acc(train)=7.55e-01, error(valid)=7.96e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 8.2s to complete
#     error(train)=7.92e-01, acc(train)=7.54e-01, error(valid)=8.00e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 8.8s to complete
#     error(train)=7.90e-01, acc(train)=7.54e-01, error(valid)=7.96e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 7.5s to complete
#     error(train)=7.87e-01, acc(train)=7.55e-01, error(valid)=7.96e-01, acc(valid)=7.47e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 8.5s to complete
#     error(train)=7.86e-01, acc(train)=7.55e-01, error(valid)=7.95e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 9.0s to complete
#     error(train)=7.87e-01, acc(train)=7.55e-01, error(valid)=7.93e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 7.5s to complete
#     error(train)=7.81e-01, acc(train)=7.57e-01, error(valid)=7.94e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 7.6s to complete
#     error(train)=7.82e-01, acc(train)=7.57e-01, error(valid)=7.94e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 7.4s to complete
#     error(train)=7.84e-01, acc(train)=7.57e-01, error(valid)=7.90e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 7.3s to complete
#     error(train)=7.82e-01, acc(train)=7.56e-01, error(valid)=7.89e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 7.2s to complete
#     error(train)=7.81e-01, acc(train)=7.58e-01, error(valid)=7.88e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 7.2s to complete
#     error(train)=7.82e-01, acc(train)=7.55e-01, error(valid)=7.91e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 7.6s to complete
#     error(train)=7.75e-01, acc(train)=7.58e-01, error(valid)=7.86e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 7.2s to complete
#     error(train)=7.77e-01, acc(train)=7.57e-01, error(valid)=7.84e-01, acc(valid)=7.49e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 7.6s to complete
#     error(train)=7.73e-01, acc(train)=7.59e-01, error(valid)=7.82e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 7.7s to complete
#     error(train)=7.69e-01, acc(train)=7.58e-01, error(valid)=7.75e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 7.6s to complete
#     error(train)=7.71e-01, acc(train)=7.59e-01, error(valid)=7.80e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 7.6s to complete
#     error(train)=7.66e-01, acc(train)=7.60e-01, error(valid)=7.76e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 7.9s to complete
#     error(train)=7.75e-01, acc(train)=7.57e-01, error(valid)=7.83e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 7.8s to complete
#     error(train)=7.64e-01, acc(train)=7.60e-01, error(valid)=7.76e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 7.7s to complete
#     error(train)=7.71e-01, acc(train)=7.60e-01, error(valid)=7.83e-01, acc(valid)=7.54e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 8.0s to complete
#     error(train)=7.69e-01, acc(train)=7.59e-01, error(valid)=7.79e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 7.6s to complete
#     error(train)=7.63e-01, acc(train)=7.61e-01, error(valid)=7.70e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 7.5s to complete
#     error(train)=7.63e-01, acc(train)=7.61e-01, error(valid)=7.73e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 7.7s to complete
#     error(train)=7.63e-01, acc(train)=7.61e-01, error(valid)=7.70e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 8.7s to complete
#     error(train)=7.64e-01, acc(train)=7.62e-01, error(valid)=7.69e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 8.9s to complete
#     error(train)=7.63e-01, acc(train)=7.63e-01, error(valid)=7.69e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 8.9s to complete
#     error(train)=7.58e-01, acc(train)=7.64e-01, error(valid)=7.69e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 8.7s to complete
#     error(train)=7.61e-01, acc(train)=7.63e-01, error(valid)=7.71e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 7.9s to complete
#     error(train)=7.60e-01, acc(train)=7.60e-01, error(valid)=7.72e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 7.8s to complete
#     error(train)=7.55e-01, acc(train)=7.63e-01, error(valid)=7.65e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 8.0s to complete
#     error(train)=7.59e-01, acc(train)=7.62e-01, error(valid)=7.66e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 8.2s to complete
#     error(train)=7.58e-01, acc(train)=7.63e-01, error(valid)=7.68e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 8.0s to complete
#     error(train)=7.63e-01, acc(train)=7.60e-01, error(valid)=7.71e-01, acc(valid)=7.53e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 7.6s to complete
#     error(train)=7.53e-01, acc(train)=7.65e-01, error(valid)=7.63e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 7.8s to complete
#     error(train)=7.54e-01, acc(train)=7.64e-01, error(valid)=7.69e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 7.3s to complete
#     error(train)=7.58e-01, acc(train)=7.64e-01, error(valid)=7.66e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 7.5s to complete
#     error(train)=7.48e-01, acc(train)=7.66e-01, error(valid)=7.58e-01, acc(valid)=7.64e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 7.7s to complete
#     error(train)=7.54e-01, acc(train)=7.61e-01, error(valid)=7.60e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 8.5s to complete
#     error(train)=7.57e-01, acc(train)=7.62e-01, error(valid)=7.67e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 8.2s to complete
#     error(train)=7.54e-01, acc(train)=7.63e-01, error(valid)=7.61e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 13.5s to complete
#     error(train)=7.57e-01, acc(train)=7.63e-01, error(valid)=7.68e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 9.8s to complete
#     error(train)=7.55e-01, acc(train)=7.61e-01, error(valid)=7.63e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 8.0s to complete
#     error(train)=7.58e-01, acc(train)=7.61e-01, error(valid)=7.68e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 8.0s to complete
#     error(train)=7.51e-01, acc(train)=7.65e-01, error(valid)=7.58e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 7.6s to complete
#     error(train)=7.54e-01, acc(train)=7.61e-01, error(valid)=7.65e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 8.3s to complete
#     error(train)=7.52e-01, acc(train)=7.62e-01, error(valid)=7.62e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 8.1s to complete
#     error(train)=7.49e-01, acc(train)=7.64e-01, error(valid)=7.58e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 10.3s to complete
#     error(train)=7.52e-01, acc(train)=7.63e-01, error(valid)=7.56e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 8.2s to complete
#     error(train)=7.54e-01, acc(train)=7.64e-01, error(valid)=7.61e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 7.6s to complete
#     error(train)=7.50e-01, acc(train)=7.64e-01, error(valid)=7.57e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 10.4s to complete
#     error(train)=7.47e-01, acc(train)=7.66e-01, error(valid)=7.55e-01, acc(valid)=7.63e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 8.3s to complete
#     error(train)=7.47e-01, acc(train)=7.65e-01, error(valid)=7.59e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 7.9s to complete
#     error(train)=7.47e-01, acc(train)=7.65e-01, error(valid)=7.56e-01, acc(valid)=7.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 8.3s to complete
#     error(train)=7.51e-01, acc(train)=7.63e-01, error(valid)=7.57e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 8.4s to complete
#     error(train)=7.50e-01, acc(train)=7.64e-01, error(valid)=7.59e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 7.8s to complete
#     error(train)=7.45e-01, acc(train)=7.66e-01, error(valid)=7.56e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 7.4s to complete
#     error(train)=7.43e-01, acc(train)=7.67e-01, error(valid)=7.55e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 7.2s to complete
#     error(train)=7.50e-01, acc(train)=7.63e-01, error(valid)=7.59e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 7.8s to complete
#     error(train)=7.45e-01, acc(train)=7.65e-01, error(valid)=7.55e-01, acc(valid)=7.62e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 7.0s to complete
#     error(train)=7.46e-01, acc(train)=7.65e-01, error(valid)=7.55e-01, acc(valid)=7.59e-01

# %% [markdown]
# # PartA final. Use the test set to access the accuracy of DNN architecture you choose

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule,RMSPropLearningRule,AdamLearningRule
from mlp.optimisers import Optimiser
from mlp.layers import BatchNormalizationLayer
#setup hyperparameters
incl_prob = 0.5
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    DropoutLayer(rng, incl_prob),
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    BatchNormalizationLayer(hidden_dim),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    BatchNormalizationLayer(hidden_dim),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])



error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule_Adam = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('the final test set\n\n')
def test_model_and_plot_stats(
        model, error, learning_rule, valid_data,test_data,num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, valid_data,test_data,data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(valid)','error(test)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    ax_1.savefig('PartA_final_error.pdf')
    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(valid)', 'acc(test)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    ax_2.savefig('PartA_final_acc.pdf')
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

_= test_model_and_plot_stats(
    model, error, learning_rule_Adam, valid_data, test_data, num_epochs, stats_interval, notebook=True)
# Out:
# the final test set
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-70be82d968ef> in <module>()
#      73
#      74 _= test_model_and_plot_stats(
# ---> 75     model, error, learning_rule_Adam, train_data, valid_data, test_data, num_epochs, stats_interval, notebook=True)
#      76
#
# <ipython-input-12-70be82d968ef> in test_model_and_plot_stats(model, error, learning_rule, train_data, valid_data, test_data, num_epochs, stats_interval, notebook)
#      46     # Use the created objects to initialise a new Optimiser instance.
#      47     optimiser = Optimiser(
# ---> 48         model, error, learning_rule, train_data, valid_data,test_data,data_monitors, notebook=notebook)
#      49
#      50     # Run the optimiser for 5 epochs (full passes through the training set)
#
# TypeError: __init__() got multiple values for argument 'notebook'

# %% [markdown]
# ## PartB 5. Construct and train networks containing one and two convolutional layers, and max-pooling layers,
# using the EMNIST Balanced data, reporting your experimental results. As a default use convolutional
# kernels of dimension 55 (stride 1) and pooling regions of 22 (stride 2, hence non-overlapping).

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer,DropoutLayer,MaxPoolingLayer,ReshapeLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule,RMSPropLearningRule,AdamLearningRule
from mlp.optimisers import Optimiser
from mlp.layers import ConvolutionalLayer



#setup hyperparameters
incl_prob = 0.5
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

train_data.reset()
valid_data.reset()


input_dim1 = 28
input_dim2 = 28

kernel_dim_1 = 5
kernel_dim_2 = 5

featureMaps1 = 5
featureMaps2 = 10

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

# activation_layer = ConvolutionalLayer(num_input_channels=3, num_output_channels=2, input_dim_1=4, input_dim_2=4,
#                                       kernel_dim_1=2, kernel_dim_2=2)

print('build model')
#one CNN layer
model_oneLayer = MultipleLayerModel([

    ReshapeLayer(output_shape=(1,28,28)),

    ConvolutionalLayer(num_input_channels=1, num_output_channels=featureMaps1, input_dim_1=input_dim1, input_dim_2=input_dim2,
                                      kernel_dim_1=kernel_dim_1, kernel_dim_2=kernel_dim_2),

    ReluLayer(),

    MaxPoolingLayer(pool_size=2),

    ReshapeLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(5*12*12, output_dim, weights_init, biases_init)
])

#two CNN layer
model_twoLayer = MultipleLayerModel([

    ReshapeLayer(output_shape=(1,28,28)),

    ConvolutionalLayer(num_input_channels=1, num_output_channels=featureMaps1, input_dim_1=input_dim1, input_dim_2=input_dim2,
                                      kernel_dim_1=kernel_dim_1, kernel_dim_2=kernel_dim_2),

    ReluLayer(),

    MaxPoolingLayer(pool_size=2),
    ConvolutionalLayer(5,10,12,12,5,5),
    ReluLayer(),
    MaxPoolingLayer(pool_size=2),
    ReshapeLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(160, output_dim, weights_init, biases_init)
])


error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule

learning_rule_Adam = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('one CNNLayer\n\n')
[stats_oneLayer, keys_oneLayer] = train_model_and_plot_stats(
    model_oneLayer, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('two CNNLayer\n\n')
[stats_twoLayer, keys_twoLayer] = train_model_and_plot_stats(
    model_twoLayer, error, learning_rule_Adam, train_data, valid_data, num_epochs, stats_interval, notebook=True)


# Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_oneLayer.shape[0]) * stats_interval,
            stats_oneLayer[1:, keys_oneLayer[k]], label='one CNN layer')
    ax_1.plot(np.arange(1, stats_twoLayer.shape[0]) * stats_interval,
            stats_twoLayer[1:, keys_twoLayer[k]], label='two CNN layer')


ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different CNN layers in the training dataset ')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('PartB5_CNNLayers_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_oneLayer.shape[0]) * stats_interval,
            stats_oneLayer[1:, keys_oneLayer[k]], label='one CNN layer')
    ax_2.plot(np.arange(1, stats_twoLayer.shape[0]) * stats_interval,
            stats_twoLayer[1:, keys_twoLayer[k]], label='two CNN layer')


ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different CNN layers in the valid dataset')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('PartB5_CNNLayers_valid_error.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_oneLayer.shape[0]) * stats_interval,
            stats_oneLayer[1:, keys_oneLayer[k]], label='one CNN layer')
    ax_3.plot(np.arange(1, stats_twoLayer.shape[0]) * stats_interval,
            stats_twoLayer[1:, keys_twoLayer[k]], label='two CNN layer')

ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different CNN layers in the training dataset ')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('PartB5_CNNLayers_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_oneLayer.shape[0]) * stats_interval,
            stats_oneLayer[1:, keys_oneLayer[k]], label='one CNN layer')
    ax_4.plot(np.arange(1, stats_twoLayer.shape[0]) * stats_interval,
            stats_twoLayer[1:, keys_twoLayer[k]], label='two CNN layer')


ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different CNN layers in the vaild dataset ')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('PartB5_CNNLayers_valid_acc.pdf') # Save figure to current directory in PDF format
